# %% [markdown]
# Connect to Google Drive.

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# Access the data and determine the following:
# *   If Tweet is related to Climate Change
# *   If Tweet is sentimental or not

# %%
import requests, re, nltk
nltk.download('stopwords')
from collections import Counter
import operator

import json

# we may not care about the usage of stop words
stop_words = nltk.corpus.stopwords.words('english') + [
 'ut', '\'re','.', ',', '--', '\'s', '?', ')', '(', ':', '\'',
 '\"', '-', '}', '{', '&', '|', 'rt', '', u'\u2014' ]

#-------------------------------------------------------------------------------------------------------------------

# We also want to remove special characters, quotes, etc. from each word
def cleanWord (w):
    # r in r'[.,"\']' tells to treat \ as a regular character 
    # but we need to escape ' with \'
    # any character between the brackets [] is to be removed 
    wn = re.sub('[,"\.\'&\|:@>*;/=]', "", w)
    # get rid of numbers
    return re.sub('^[0-9\.]*$', "", wn)
  
#-------------------------------------------------------------------------------------------------------------------
  
def TweetAnalyze():

  #obtain .json file data
  file = open("/content/gdrive/My Drive/ECE-545 - Fundamentals of Digital Archeology/sample_vannostrand.json")
  data = json.load(file)
  file.close()
  
  climateChangeCount = 0 #total number of Tweets specific to climate change
  naturalDisasterCount = 0 #total number of Tweets specific to natural disasters
  changeAccept = 0 #total number of Tweets specific to climate change acceptance
  changeDeny = 0 #total number of Tweets specific to climate change denial
  posSentCount = 0 #total number of Tweets specific to sentamental Tweets
  negSentCount = 0 #total number of Tweets specific to non-sentamental Tweets
  
  # - - - - - - - - - - - - - - - - - - - - - - - - - - - -
  
  #lists of words to determine Tweet classification
  #ALL WORDS ARE LOWERCASE
  #ALSO ONLY USING STEM WORDS
  climateWords = ['climat', 'chang', 'global', 'warm']
  disastersWords = ['hurrican', 'earthquake', 'tornado']
  acceptWords = ['real', 'believ', 'deterior', 'grave', 'danger', 'ignor', 'warn']
  denyWords = ['fake', 'hoax', 'deni', 'deny', 'doubt', 'scheme', 'scam']
  posSentWords = ['hope', 'wish', 'best', 'pray', 'share', 'great', 'well', 'offer', 'resolv']
  negSentWords = ['hate', 'stupid', 'offens', 'fear', 'fuck', 'crazi', 'shit', 'wast', 'disgrac', 'scold', 'anxieti']
  
  #noticed most regarding Trump are mocking him for not believing in climate change
  presidentWords = ['trump', 'presid']
  
  #-----------------------------------------------------------------------------------------------------

  #NOTE: data[#] is a dictionary, so each tweet is a dictionary
  #NOTE: 1,000 tweets in data
  for dataDict in data:
  
    #Debugging
    #print(dataDict)
    #input("wait")
    
    if(dataDict[u'lang']== u'en'): #if language of tweet is English
    #currently can only check for Tweets in English
    
      #-------------------------------------------------------------------------------------------------
    
      #print out important fields
      #--------------------------
    
      #Debugging
      #print(dataDict)
      #input("wait")
    
      #return names
      #------------
      #print("Screen name: " + dataDict["user"]["screen_name"]) #Twitter profile name
      #print("Full Name: " + dataDict["user"]["name"]) #full name associated with profile
    
      #- - - - - - - - - - - - -
    
      #return user ID
      #--------------
      #print("Consistent User ID: " + dataDict["user"]["id_str"]) #string version of user ID
    
      #- - - - - - - - - - - - -
    
      #also return retweet status
      #if 'retweeted_status' in dataDict:
      #  print("Retweet!")
      
      #-------------------------------------------------------------------------------------------------

      #return Tweet text and determine "context" of the Tweet
      #------------------------------------------------------
    
      if 'extended_tweet' in dataDict: #if there is an extended Tweet (sometimes there isn't)
        #print("Extended Tweet: " + dataDict["extended_tweet"]["full_text"]) #full Tweet text
        
        # split string into an array of words using any sequence of spaces "\s+" 
        wds = re.findall('\w+',dataDict["extended_tweet"]["full_text"])
        
      else: #if there is no extended Tweet
        #print("Tweet: " + dataDict["text"]) #Tweet text (cut off if too long)
        
        # split string into an array of words using any sequence of spaces "\s+" 
        wds = re.findall('\w+',dataDict["text"])
        
      # remove periods, commas, etc stuck to the edges of words
      for i in range(len(wds)):
        wds [i] = cleanWord (wds [i])
        
      #convert all words to lowercase
      wds = [word.lower() for word in wds]
      
      #leave only the stems of words using ntlk's Snowball stemmer
      snowball = nltk.stem.SnowballStemmer('english')
      wds = [snowball.stem(word) for word in wds]
      
      # If satisfied with results, lets go to the next step: calculate frequencies
      # We can write a loop to create a dictionary, but 
      # there is a special function for everything in python
      # in particular for counting frequencies (like function table() in R)
      wf = Counter (wds)
      
      # Remove stop words from the dictionary wf
      for k in stop_words:
        wf. pop(k, None)
      
      #- - - - - - - - - - - - -
      
      #determine Tweet classification
      
      #debugging
      print(wf)
      
      beliefCheck = 0
      sentCheck = 0
      climateFlag = False
      disasterFlag = False
      presidentOverride = False
      
      for words in wf:
        #determine flags
        
        #debugging
        #print(words)
        
        if words in climateWords:
          climateFlag = True
        if words in disastersWords:
          disasterFlag = True
        if (words == 'Trump') or (words == 'president'):
          presidentOverride = True
        
        #determine sentimental viewpoint and belief based on frequency
        if words in acceptWords:
          beliefCheck += 1
        if words in denyWords:
          beliefCheck -= 1
        if words in posSentWords:
          sentCheck += 1
        if words in negSentWords:
          sentCheck -= 1
      
      #- - - - - - - - - - - - -
      
      #return classification
      if climateFlag:
        #print("Climate Change Tweet")
        #print("\n")
        climateChangeCount += 1
      
      if disasterFlag:
        #print("Natural Disaster Tweet")
        #print("\n")
        naturalDisasterCount += 1
      
      if (not presidentOverride): #if not a President Trump related Tweet
        
        #for Climate Change belief check
        if climateFlag:
          if (beliefCheck > 0):
            #print("Belief Tweet")
            #print("\n")
            changeAccept += 1
          elif (beliefCheck < 0):
            #print("Deny Tweet")
            #print("\n")
            changeDeny += 1
          #else:
            #print("Viewpoint unknown")
            #print("\n")
            
        #for sentamentality check
        if (sentCheck > 0):
          #print("Sentamental Tweet")
          #print("\n")
          posSentCount += 1
        elif (sentCheck < 0):
          #print("Not Sentamental Tweet")
          #print("\n")
          negSentCount += 1
      
      elif (climateFlag and presidentOverride): #if Trump and Climate Change specific
        #print("Trump Climate Change Rant Tweet")
        #print("\n")
        changeAccept += 1
        negSentCount += 1
        
      #-------------------------------------------------------------------------------------------------
    
      #if(next(iter(data)) != None): #for keeping this legible, separate tweets if there's more
      #  print("\n")
      #  print("-----------------------------------------------------------------------------")
      #  print("\n")

  #-----------------------------------------------------------------------------------------------------

  #print final calculations
  print("Number of Climate Change Tweets: " + str(climateChangeCount))
  print("Number of Natural Disaster Tweets: " + str(naturalDisasterCount))
  print("Number of Climate Change Acceptance Tweets: " + str(changeAccept))
  print("Number of Climate Change Denial Tweets: " + str(changeDeny))
  print("Number of Sentamental Tweets: " + str(posSentCount))
  print("Number of Non-sentamental Disaster Tweets: " + str(negSentCount))

#-------------------------------------------------------------------------------------------------------------------
#call the TweetAnalyze ("main") function
TweetAnalyze()
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Counter({'craigabriel': 1, 'tell': 1, 'https': 1, 'co': 1, 'hdayk3gnzw': 1})
# Counter({'plant': 2, 'scobi': 1, 'new': 1, 'zealand': 1, 'pm': 1, 'jacindaardern': 1, 'join': 1, 'treesthatcount': 1, 'million': 1, 'tree': 1, 'mitig': 1, 'climat': 1, 'chang': 1})
# Counter({'extinctionr': 1, 'everyon': 1, 'understand': 1, 'actual': 1, 'need': 1, 'someth': 1, 'much': 1, 'urgent': 1, 'situat': 1, 'amp': 1, 'onboa': 1})
# Counter({'indivisible410': 1, 'file': 1, 'thing': 1, 'gonna': 1, 'sign': 1, 'senatorcardin': 1, 'chrisvanhollen': 1, 'dem': 1, 'say': 1})
# Counter({'senwhitehous': 1, 'chamberofcarbon': 1, 'oil': 1, 'compani': 1, 'like': 1, 'paid': 1, 'accomplic': 1, 'support': 1, 'broad': 1, 'swath': 1, 'corpora': 1})
# Counter({'michaelpolanyi': 1, 'obes': 1, 'undernutrit': 1, 'global': 1, 'warm': 1, 'share': 1, 'common': 1, 'caus': 1, 'power': 1, 'commerci': 1, 'interest': 1, 'promot': 1, 'overcon': 1})
# Counter({'senatorrisch': 1, 'senat': 1, 'urg': 1, 'reject': 1, 'david': 1, 'bernhardt': 1, 'doidepsec': 1, 'interior': 1, 'deserv': 1, 'better': 1, 'fossil': 1, 'fuel': 1, 'lobbyist': 1, 'vicious': 1, 'contempt': 1, 'wildlif': 1, 'deni': 1, 'climat': 1, 'chang': 1, 'urgent': 1, 'crisi': 1, 'stopbernhardt': 1, 'seaturtles_org': 1})
# Counter({'aoc': 1, 'love': 1, 'everyth': 1, 'gop': 1, 'attack': 1, 'ad': 1, 'republican': 1, 'underestim': 1, 'intellig': 1, 'bc': 1, 'invit': 1, 'peopl': 1, 'home': 1, 'amp': 1, 'talk': 1, 'abou': 1})
# Counter({'definit': 2, 'fordnat': 1, 'accept': 1, 'fed': 1, 'disabl': 1, 'climat': 1, 'chang': 1, 'got': 1})
# Counter({'weather': 2, 'felst': 1, '15h': 1, 'current': 1, 'wind': 1, 'wnw': 1, 'gust': 1, 'temperatur': 1, 'c': 1, 'humid': 1, 'pressur': 1, 'hpa': 1, 'rain': 1, 'mm': 1, 'solar': 1, 'radiat': 1, 'w': 1, 'm²': 1, 'uv': 1, 'index': 1, 'moder': 1, 'https': 1, 'co': 1, 'wjrwupjuss': 1, 'weathercloud': 1})
# Counter({'lessthelesbian': 1, 'im': 1, 'gonna': 1, 'need': 1, 'guy': 1, 'watch': 1, 'show': 1, 'inform': 1, 'kill': 1, 'planet': 1, 'affect': 1, 'anima': 1})
# Counter({'cnnbrk': 1, 'massiv': 1, 'feder': 1, 'climat': 1, 'chang': 1, 'report': 1, 'due': 1, 'next': 1, 'month': 1, 'today': 1, 'warn': 1, 'devast': 1, 'health': 1, 'econom': 1, 'cost': 1})
# Counter({'believ': 2, 'age': 2, 'alyssa_milano': 1, 'dan': 1, 'rather': 1, 'ask': 1, 'trump': 1, 'margin': 1, 'santa': 1, 'climat': 1, 'chang': 1})
# Counter({'care': 3, 'nuclear': 2, 'power': 2, 'jimmygomezca': 1, 'keep': 1, 'exist': 1, 'plant': 1, 'run': 1, 'doe': 1, 'everyon': 1, 'dc': 1, 'climat': 1, 'wind': 1, 'solar': 1, 'nation': 1, 'provid': 1, 'includ': 1, 'home': 1, 'state': 1, 'diablo': 1, 'canyon': 1, 'largest': 1, 'sourc': 1, '0c': 1})
# Counter({'charliedaniel': 1, 'global': 1, 'warm': 1, 'hoax': 1, 'scare': 1, 'tactic': 1, 'take': 1, 'power': 1, 'everi': 1, 'facet': 1, 'life': 1, 'peopl': 1, 'vacil': 1})
# Counter({'solar': 1, 'need': 1, 'layout': 1})
# Counter({'hillaryclinton': 1, 'real': 1, 'nation': 1, 'emerg': 1, 'relentless': 1, 'gun': 1, 'violenc': 1, 'children': 1, 'separ': 1, 'famili': 1, 'border': 1, 'c': 1})
# Counter({'big': 1, 'support': 1, 'clean': 1, 'energi': 1, 'know': 1, 'get': 1, 'fossil': 1, 'fuel': 1, 'discuss': 1, 'ask': 1, 'drquest': 1, 'ueaenv': 1, 'journey': 1, 'antarctica': 1, 'scientist': 1, 'think': 1, 'trump': 1, 'latest': 1, 'climat': 1, 'tweet': 1, 'https': 1, 'co': 1, 'di8muks3zo': 1, 'via': 1, 'rollingston': 1})
# Counter({'abbygov': 1, 'republican': 1, 'music': 1, 'featur': 1, 'hit': 1, 'defi': 1, 'climat': 1, 'chang': 1, 'im': 1, 'throw': 1, 'away': 1, 'shotgun': 1, 'cell': 1, 'block': 1})
# Counter({'cpc_hq': 1, 'destroy': 1, 'environ': 1, 'plan': 1, 'climat': 1, 'chang': 1})
# Counter({'avexfn': 1, 'solarwisp': 1, 'coltmunzi': 1, 'munzi': 1, 'check': 1, 'owner': 1, 'chat': 1, 'storm': 1, 'bbi': 1, 'awh': 1, 'onli': 1, 'colt': 1, 'member': 1, 'like': 1, 'favorit': 1, 'guy': 1, 'sola': 1})
# Counter({'mythicalireland': 1, 'post': 1, 'https': 1, 'co': 1, 'uv6cvsoksj': 1})
# Counter({'domschien': 1, 'releas': 1, 'untangl': 1, 'podcast': 1, 'interview': 1, 'interest': 1, 'communiti': 1, 'project': 1, 'member': 1, 'bring': 1})
# Counter({'ghostpanth': 1, 'crazi': 1, 'shit': 1, 'incred': 1, 'rememb': 1, 'absolut': 1, 'dwarf': 1, 'global': 1, 'warm': 1})
# Counter({'co': 3, 'histori': 2, 'https': 2, 'netizenfour': 1, 'betweenmyth': 1, 'nikitaggarw': 1, 'floridi': 1, 'shannonvallor': 1, 'aimeevanrobot': 1, 'alan_winfield': 1, 'mediamocraci': 1, 'robmccargow': 1, 'oiioxford': 1, 'frossi_t': 1, 'rosariataddeo': 1, 'johnchaven': 1, 'iemfa': 1, 'share': 1, 'ani': 1, 'period': 1, 'absent': 1, 'tragedi': 1, 'amp': 1, 'suffer': 1, 'eh': 1, 'regardless': 1, 'agre': 1, 'must': 1, 'hv': 1, 'rri': 1, 'mdsafetech': 1, 'slorant': 1, 'learn': 1, 'much': 1, 'unit': 1, 'forc': 1, 'energi': 1, 'senblumenth': 1, 'also': 1, 'see': 1, 'dod': 1, 'report': 1, '5g': 1, 'ecosystem': 1, 'vtxvsswuqi': 1, 'jvo5dznvkb': 1})
# Counter({'nick_boro1': 1, 'strang': 1, 'announc': 1, 'befor': 1, 'meaning': 1, 'vote': 1, 'may': 1, 'think': 1, 'remoan': 1, 'keep': 1, 'power': 1})
# Counter({'talk': 2, 'snazzyq': 1, 'peopl': 1, 'great': 1, 'appl': 1, 'ecosystem': 1, 'https': 1, 'co': 1, 'bhbjtpysu7': 1})
# Counter({'robgmacfarlan': 1, 'across': 1, 'landscap': 1, 'grip': 1, 'unpreced': 1, 'heatwav': 1, 'local': 1, 'peopl': 1, 'spoke': 1, 'beauti': 1, 'winter': 1, 'sad': 1, 'long': 1})
# Counter({'veri': 2, 'theeagleist': 1, 'whi': 1, 'pipelin': 1, 'crucial': 1, 'https': 1, 'co': 1, 'hghr3mryz5': 1})
# Counter({'ciilqaatgurl': 1, 'liter': 1, 'devast': 1, 'disrupt': 1, 'entir': 1, 'ecosystem': 1, 'food': 1, 'chain': 1, 'noth': 1, 'terrifi': 1})
# Counter({'crazyinnasia': 1, 'solar': 1, 'farm': 1, 'china': 1, 'https': 1, 'co': 1, 'hyihkitsm0': 1})
# Counter({'crushcuitur': 1, 'scari': 1, 'know': 1, 'probabl': 1, 'wont': 1, 'aliv': 1, 'kid': 1, 'grow': 1, 'old': 1, 'togeth': 1, 'someon': 1, 'becaus': 1, 'fact': 1})
# Counter({'one': 2, 'new': 2, 'djrothkopf': 1, 'show': 1, 'centrist': 1, 'idea': 1, 'propos': 1, 'center': 1, 'better': 1, 'deal': 1, 'w': 1, 'econom': 1, 'insecur': 1, 'climat': 1, 'chang': 1})
# Counter({'vanessacvenus': 1, 'watch': 1, 'ocasio': 1, 'cortez': 1, 'blow': 1, 'gasket': 1, 'say': 1, 'miami': 1, 'exist': 1, 'year': 1, 'due': 1, 'climat': 1, 'chang': 1, 'https': 1, 'co': 1, 'okmlnte8': 1})
# Counter({'greenbenali': 1, 'dare': 1, 'green': 1, 'parti': 1, 'contrari': 1, 'opinion': 1, 'labour': 1, 'biggest': 1, 'issu': 1, 'day': 1, 'https': 1, 'co': 1, 'nyduwyjyxb': 1})
# Counter({'travishelwig': 1, 'fuck': 1, 'point': 1, 'paper': 1, 'straw': 1, 'gonna': 1, 'stop': 1, 'global': 1, 'warm': 1, 'regul': 1, 'corpor': 1, 'https': 1, 'co': 1})
# Counter({'fact': 2, 'govhowarddean': 1, 'wonder': 1, 'alexandria': 1, 'c': 1, 'becom': 1, 'obsess': 1, 'racist': 1, 'fox': 1, 'anyth': 1})
# Counter({'canadiangreen': 1, 'everi': 1, 'countri': 1, 'keep': 1, 'wait': 1, 'act': 1, 'crisi': 1, 'worsen': 1, 'canada': 1, 'need': 1, 'real': 1, 'leadership': 1, 'https': 1})
# Counter({'crushcuitur': 1, 'scari': 1, 'know': 1, 'probabl': 1, 'wont': 1, 'aliv': 1, 'kid': 1, 'grow': 1, 'old': 1, 'togeth': 1, 'someon': 1, 'becaus': 1, 'fact': 1})
# Counter({'take': 1, 'develop': 1, 'ecosystem': 1, 'survey': 1, 'jetbrain': 1, 'https': 1, 'co': 1, 'pqokgytmno': 1})
# Counter({'data': 3, 'haoyuan': 1, 'keynot': 1, 'slide': 1, 'a10': 1, 'amp': 1, 'ai': 1, 'confer': 1, 'sever': 1, 'week': 1, 'ago': 1, 'ecosystem': 1, 'https': 1, 'co': 1, 'jcb1rr3ygi': 1, 'alluxio': 1, 'ml': 1})
# Counter({'gdg': 1, 'new': 1, 'orlean': 1, 'tonight': 1, 'join': 1, 'us': 1, 'learn': 1, 'recur': 1, 'run': 1, 'dev': 1, 'ecosystem': 1, 'ben': 1, 'eckel': 1, 'https': 1, 'co': 1, 'ijul5ocpiw': 1})
# Counter({'jjkmoonchiid': 1, 'solar': 1, 'tri': 1, 'greet': 1, 'jimin': 1, 'see': 1, 'reaction': 1, 'afterward': 1, 'cute': 1, 'shkdhjfkhfj': 1, 'https': 1, 'co': 1, 'n6': 1})
# Counter({'bjornlomborg': 1, 'great': 1, 'talk': 1, 'climat': 1, 'scientist': 1, 'john': 1, 'christi': 1, 'first': 1, 'satellit': 1, 'temperatur': 1, 'data': 1, 'seri': 1, 'https': 1, 'co': 1, 'ow22vcitcq': 1})
# Counter({'markdic': 1, 'meet': 1, 'greta': 1, 'thunberg': 1, 'aoc': 1, 'senior': 1, 'advisor': 1, 'global': 1, 'warm': 1, 'https': 1, 'co': 1, 'tfnta1npq3': 1})
# Counter({'johnjharwood': 1, 'husband': 1, 'billionair': 1, 'coal': 1, 'mine': 1, 'magnat': 1, 'https': 1, 'co': 1, 'kliu7orywg': 1})
# Counter({'dwallacewel': 1, 'wallac': 1, 'well': 1, 'resolv': 1, 'offer': 1, 'someth': 1, 'standard': 1, 'narrat': 1, 'climat': 1, 'chang': 1, 'collect': 1, 'action': 1})
# Counter({'leodicaprio': 1, 'scienc': 1, 'clear': 1, 'must': 1, 'keep': 1, 'global': 1, 'temperatur': 1, 'rise': 1, 'c': 1, 'need': 1, 'govern': 1, 'compani': 1, 'citizen': 1})
# Counter({'stupid': 2, 'scandal': 2, 'happen': 2, 'wish': 1, 'everyon': 1, 'would': 1, 'put': 1, 'energi': 1, 'climat': 1, 'chang': 1, 'lgbtq': 1, 'right': 1, 'cheat': 1, 'last': 1, 'year': 1, 'earth': 1, 'death': 1, 'becaus': 1, 'destroy': 1, 'yous': 1, 'anymor': 1})
# Counter({'berryeontan': 1, 'kid': 1, 'born': 1, 'grow': 1, 'wanna': 1, 'climat': 1, 'chang': 1, 'https': 1, 'co': 1, 'gn5hpwaoux': 1})
# Counter({'understand': 2, 'sgonnawin2020': 1, 'bigger': 1, 'pictur': 1, 'climat': 1, 'chang': 1, 'must': 1, 'first': 1, 'nwo': 1, 'un': 1, 'role': 1, 'h': 1})
# Counter({'scienc': 2, 'age': 2, 'come': 2, 'govt': 2, 'lmfaooooooooo': 1, 'semi': 1, 'annual': 1, 'remind': 1, 'behind': 1, 'global': 1, 'warm': 1, 'junk': 1, 'also': 1, 'parent': 1, 'school': 1, 'taught': 1, 'ice': 1, 'pay': 1, 'scientist': 1, 'w': 1, 'report': 1, 'back': 1, 'theori': 1})
# Counter({'doubt': 1, 'veri': 1, 'much': 1, 'coupl': 1, 'snowfal': 1, 'winter': 1, 'vancouv': 1, 'meaning': 1, 'attribut': 1, 'climat': 1, 'chang': 1, 'live': 1, 'life': 1, 'expos': 1, 'scienc': 1, 'mockeri': 1})
# Counter({'emoblackthot': 1, 'overwhelm': 1, 'white': 1, 'men': 1, 'amp': 1, 'women': 1, 'vote': 1, 'red': 1, 'self': 1, 'interest': 1, 'never': 1, 'chang': 1, 'becaus': 1})
# Counter({'kylegriffin1': 1, 'pelosi': 1, 'announc': 1, 'today': 1, 'hous': 1, 'dem': 1, 'introduc': 1, 'hr': 1, 'climat': 1, 'action': 1, 'act': 1, 'aim': 1, 'keep': 1, 'u': 1})
# Counter({'thelibragroup': 1, 'edit': 1, 'vesser': 1, 'former': 1, 'countri': 1, 'manag': 1, 'romania': 1, 'euroenergi': 1, 'appoint': 1, 'ceo': 1, 'usa': 1, 'base': 1, 'renew': 1, 'energ': 1})
# Counter({'laylaalisha11': 1, 'democrat': 1, 'maria': 1, 'harf': 1, 'scold': 1, 'pete': 1, 'hegseth': 1, 'interrupt': 1, 'migrant': 1, 'flee': 1, 'climat': 1, 'chang': 1, 'narrat': 1, 'laughter': 1})
# Counter({'jim_pembrok': 1, 'like': 1, 'morrison': 1, 'drag': 1, 'kick': 1, 'amp': 1, 'scream': 1, 'bankingrc': 1, 'last': 1, 'minut': 1, 'liberalaus': 1, 'presid': 1, 'nick': 1, 'greiner': 1})
# Counter({'mike': 1, 'landando': 1, '12h': 1, 'current': 1, 'weather': 1, 'wind': 1, 'calm': 1, 'gust': 1, 'mph': 1, 'temperatur': 1, 'f': 1, 'humid': 1, 'pressur': 1, 'inhg': 1, 'rain': 1, 'solar': 1, 'radiat': 1, 'w': 1, 'm²': 1, 'uv': 1, 'index': 1, 'moder': 1, 'https': 1, 'co': 1, 'g54wfarcfu': 1, 'weathercloud': 1})
# Counter({'realsaavedra': 1, 'break': 1, 'nanci': 1, 'pelosi': 1, 'exclud': 1, 'alexandria': 1, 'ocasio': 1, 'cortez': 1, 'new': 1, 'climat': 1, 'chang': 1, 'committe': 1, 'https': 1, 'co': 1, 'yorne3wffz': 1})
# Counter({'crushcuitur': 1, 'scari': 1, 'know': 1, 'probabl': 1, 'wont': 1, 'aliv': 1, 'kid': 1, 'grow': 1, 'old': 1, 'togeth': 1, 'someon': 1, 'becaus': 1, 'fact': 1})
# Counter({'crushcuitur': 1, 'scari': 1, 'know': 1, 'probabl': 1, 'wont': 1, 'aliv': 1, 'kid': 1, 'grow': 1, 'old': 1, 'togeth': 1, 'someon': 1, 'becaus': 1, 'fact': 1})
# Counter({'male': 2, 'arnulfov21': 1, 'jhw229': 1, 'polar': 1, 'bear': 1, 'alway': 1, 'eaten': 1, 'kill': 1, 'younger': 1, 'avoid': 1, 'competit': 1, 'current': 1})
# Counter({'power': 2, 'cgriwkowski': 1, 'road': 1, 'come': 1, 'handi': 1, 'futur': 1, 'eventu': 1, 'cover': 1, 'damag': 1, 'site': 1, 'tar': 1, 'sand': 1, 'solar': 1, 'panel': 1, 'wind': 1, 'provid': 1, 'competit': 1, 'price': 1, 'albertan': 1})
# Counter({'kctaz': 1, 'wast': 1, 'world': 1, 'resourc': 1, 'chase': 1, 'fantasi': 1, 'man': 1, 'control': 1, 'temperatur': 1, 'earth': 1, 'disgrac': 1, 'evil': 1, 'htt': 1})
# Counter({'total': 2, 'byungoghsolo': 1, 'holi': 1, 'sht': 1, 'solar': 1, 'eclips': 1, 'juli': 1, 'like': 1, 'dark': 1, 'mayb': 1, 'whi': 1, 'left': 1})
# Counter({'ocasio2018': 1, 'anyon': 1, 'els': 1, 'notic': 1, 'scientist': 1, 'new': 1, 'clich': 1, 'prelud': 1, 'lobbyist': 1, 'amp': 1, 'fossil': 1, 'fuel': 1, 'interest': 1, 'slip': 1})
# Counter({'think': 2, 'money': 2, 'crewcrew': 1, 'senatemajldr': 1, 'take': 1, 'oil': 1, 'refin': 1, 'affect': 1, 'stanc': 1, 'global': 1, 'warm': 1, 'scientist': 1, 'enorm': 1, 'worldwid': 1, 'conspiraci': 1, 'fudg': 1, 'satellit': 1, 'ice': 1, 'core': 1, 'data': 1, 'make': 1})
# Counter({'numeralten': 1, 'rick': 1, 'glacier': 1, 'https': 1, 'co': 1, 'tazmust6jr': 1})
# Counter({'part': 2, 'breakingnl': 1, 'amount': 1, 'carbon': 1, 'dioxid': 1, 'releas': 1, 'car': 1, 'increas': 1, 'big': 1, 'europ': 1, 'signific': 1, 'wh': 1})
# Counter({'pubaffairseu': 1, 'faroeisland': 1, 'tell': 1, 'us': 1, 'small': 1, 'state': 1, 'autonomi': 1, 'climatechang': 1, 'europp': 1, 'lse': 1, 'blog': 1, 'https': 1, 'co': 1, 'mnlbf0': 1})
# Counter({'lobbi': 3, 'climat': 2, 'chang': 2, 'cmedanski': 1, 'senkamalaharri': 1, 'interest': 1, 'work': 1, 'mere': 1, 'specul': 1, 'content': 1, 'purpos': 1, 'noth': 1, 'say': 1, 'energi': 1, 'industri': 1, 'mani': 1, 'topic': 1, 'experi': 1, 'one': 1, 'silli': 1})
# Counter({'aoc': 1, 'guess': 1, 'wsj': 1, 'editori': 1, 'page': 1, 'take': 1, 'pride': 1, 'ignor': 1, 'nation': 1, 'histori': 1, 'slaveri': 1, 'jim': 1, 'crow': 1, 'amp': 1, 'mass': 1, 'incarcer': 1})
# Counter({'kennedywlsh': 1, 'earth': 1, 'die': 1, 'least': 1, 'global': 1, 'warm': 1, 'kill': 1, 'us': 1, 'notr': 1, 'dame': 1, 'still': 1, 'stand': 1, 'https': 1, 'co': 1, 'ne': 1})
# Counter({'solarenergi': 1, 'photovolta': 1, 'panel': 1, 'work': 1, 'comprehens': 1, 'report': 1, 'solar': 1, 'pv': 1, 'renew': 1, 'alternativeenergi': 1, 'cleanenergi': 1, 'renewableenergi': 1, 'sustainableenergi': 1, 'sustain': 1, 'power': 1, 'sun': 1, 'radiat': 1, 'energi': 1, 'electr': 1, 'generat': 1, 'transmiss': 1, 'https': 1, 'co': 1, '8exvg6rxdb': 1, 'via': 1, 'flipboard': 1})
# Counter({'bbcnickrobinson': 1, 'dare': 1, 'ask': 1, 'thing': 1, 'said': 1, 'past': 1, 'amp': 1, 'view': 1, 'hold': 1, 'say': 1, 'man': 1, 'want': 1, 'take': 1, 'back': 1, 'control': 1, 'b': 1})
# Counter({'johnlundin': 1, 'second': 1, 'emot': 1, 'trump': 1, 'failur': 1, 'fight': 1, 'climat': 1, 'chang': 1, 'crime': 1, 'human': 1, 'opinion': 1, 'cnn': 1, 'https': 1})
# Counter({'pilibin_uisc': 1, 'excel': 1, 'articl': 1, 'done': 1, 'address': 1, 'problem': 1, 'pollut': 1, 'plastic': 1, 'manufactur': 1, 'fossil': 1, 'fue': 1})
# Counter({'believ': 2, 'paulwestoneden': 1, 'let': 1, 'honest': 1, 'realli': 1, 'global': 1, 'warm': 1, 'threat': 1, 'would': 1, 'everythin': 1})
# Counter({'realjameswood': 1, 'first': 1, 'step': 1, 'intellig': 1, 'popul': 1, 'control': 1, 'cull': 1, 'herd': 1, 'idiot': 1, 'liber': 1, 'https': 1, 'co': 1, 'axwmfdxpng': 1})
# Counter({'jhw229': 1, 'polar': 1, 'bear': 1, 'start': 1, 'practic': 1, 'cannib': 1, 'mother': 1, 'eat': 1, 'cub': 1, 'becaus': 1, 'drastic': 1, 'climat': 1, 'chang': 1})
# Counter({'chang': 2, 'akimcampbel': 1, 'cold': 1, 'west': 1, 'year': 1, 'least': 1, 'could': 1, 'terminolog': 1, 'pc': 1, 'climat': 1, 'seem': 1, 'incred': 1, 'touch': 1, 'long': 1, 'prime': 1, 'minist': 1, 'https': 1, 'co': 1, 'zml023ipw': 1})
# Counter({'health': 2, 'face': 1, 'multipl': 1, 'challeng': 1, 'issu': 1, 'tackl': 1, 'air': 1, 'pollut': 1, 'amp': 1, 'climat': 1, 'chang': 1, 'noncommu': 1})
# Counter({'johntrumpfankjv': 1, 'democrat': 1, 'plan': 1, 'deindustri': 1, 'america': 1, 'due': 1, 'climat': 1, 'chang': 1, 'sound': 1, 'like': 1, 'someth': 1, 'straight': 1, 'comm': 1})
# Counter({'avnet': 2, 'look': 2, 'optim': 1, 'uv': 1, 'light': 1, 'solut': 1, 'ecosystem': 1, 'goal': 1, 'help': 1, 'achi': 1})
# Counter({'mhfit': 1, 'kill': 1, 'ever': 1, 'call': 1, 'shot': 1, 'come': 1, 'canada': 1, 'see': 1, 'effect': 1, 'global': 1, 'warm': 1, 'scari': 1, 'climat': 1})
# Counter({'subcontractsind': 1, 'solarenergi': 1, 'photovolta': 1, 'panel': 1, 'work': 1, 'comprehens': 1, 'report': 1, 'solar': 1, 'pv': 1, 'renew': 1, 'alternativeenergi': 1, 'cleanenerg': 1})
# Counter({'expens': 2, 'realdonaldtrump': 1, 'trump': 1, 'claim': 1, 'environment': 1, 'respons': 1, 'support': 1, 'coal': 1, 'pollut': 1, 'environ': 1, 'current': 1, 'twice': 1, 'solar': 1, 'energi': 1})
# Counter({'existentialfish': 1, 'face': 1, 'nation': 1, 'ask': 1, 'nasa': 1, 'steven': 1, 'clark': 1, 'climat': 1, 'chang': 1, 'https': 1, 'co': 1, 'rk9n84izsf': 1})
# Counter({'therealbuzz': 1, 'one': 1, 'recogniz': 1, 'planet': 1, 'solar': 1, 'system': 1, 'magnific': 1, 'imag': 1, 'saturn': 1, 'https': 1, 'co': 1, 'lvfixrs51x': 1})
# Counter({'bjp4india': 1, 'big': 1, 'stride': 1, 'taken': 1, 'modi': 1, 'govern': 1, 'ensur': 1, 'green': 1, 'clean': 1, 'afford': 1, 'energi': 1, 'ecosystem': 1, 'india': 1, 'https': 1, 'co': 1, 'znqvhp8f': 1})
# Counter({'profterryhugh': 1, 'time': 1, 'protect': 1, 'peopl': 1, 'save': 1, 'rainforest': 1, 'greatbarrierreef': 1, 'anthropogen': 1, 'global': 1, 'heat': 1})
# Counter({'tomhal': 1, 'solar': 1, 'panel': 1, 'bloom': 1, 'like': 1, 'sunflow': 1, 'energi': 1, 'cleanenergi': 1, 'eco': 1, 'tech': 1, 'saturdaymorn': 1, 'https': 1, 'co': 1, 'rqduu5vjvw': 1})
# Counter({'billmckibben': 1, 'becaus': 1, 'typhoon': 1, 'hurrican': 1, 'highest': 1, 'tide': 1, 'look': 1, 'like': 1, 'south': 1, 'pacif': 1, 'https': 1})
# Counter({'digitalishomo': 1, 'contrari': 1, 'statement': 1, 'well': 1, 'known': 1, 'presid': 1, 'climat': 1, 'chang': 1, 'onli': 1, 'real': 1, 'also': 1, 'serious': 1, 'threat': 1, 'ar': 1})
# Counter({'_richardblack': 1, 'agre': 1, 'pep': 1, 'mountain': 1, 'evid': 1, 'show': 1, 'statement': 1, 'wrong': 1, 'never': 1, 'mind': 1, 'simpl': 1, 'logic': 1})
# Counter({'fuck': 2, 'cakedsnowbunni': 1, 'guy': 1, 'see': 1, 'happen': 1, 'give': 1, 'singl': 1, 'earth': 1, 'rapdili': 1, 'deterior': 1, 'bc': 1, 'human': 1})
# Counter({'stealingisfunni': 1, 'befor': 1, 'fuck': 1, 'love': 1, 'global': 1, 'warm': 1, 'see': 1, 'pain': 1, 'confus': 1, 'lighten': 1, 'mcqueen': 1, 'eye': 1})
# Counter({'billybobtn': 1, 'alexrossphoto': 1, 'yvandutil': 1, 'mspence6': 1, '3ghtweet': 1, 'brandondaly2018': 1, 'friendsosci': 1, 'thefuturebig': 1, 'ndpnomor': 1, 'prof_sjgreen': 1})
# Counter({'kylekuzma': 1, 'man': 1, 'stop': 1, 'playin': 1, 'fix': 1, 'ozon': 1, 'https': 1, 'co': 1, 'c1m6xn3vbn': 1})
# Counter({'kamalaharri': 1, 'californian': 1, 'endur': 1, 'deadliest': 1, 'wildfir': 1, 'state': 1, 'histori': 1, 'last': 1, 'year': 1, 'work': 1, 'togeth': 1, 'mitig': 1, 'f': 1})
# Counter({'gopchairwoman': 1, 'one': 1, 'hour': 1, 'cnn': 1, 'global': 1, 'warm': 1, 'town': 1, 'hall': 1, 'enough': 1, 'msnbc': 1, 'bring': 1, 'anoth': 1, 'time': 1, 'last': 1, 'two': 1, 'whol': 1})
# Counter({'amyklobuchar': 1, 'seen': 1, 'ice': 1, 'sheet': 1, 'truli': 1, 'massiv': 1, 'must': 1, 'take': 1, 'action': 1, 'revers': 1, 'climat': 1, 'chang': 1, 'greenland': 1, 'melt': 1})
# Counter({'yunalesckagam': 1, 'final': 1, 'fantasi': 1, 'giveaway': 1, 'ffxiv': 1, 'solar': 1, 'power': 1, 'mini': 1, 'figur': 1, 'japan': 1, 'bunch': 1, 'doubl': 1, 'recent': 1, 'haul': 1})
# Counter({'ashleyfoxmep': 1, 'say': 1, 'woman': 1, 'flew': 1, 'la': 1, 'incident': 1, 'uk': 1, 'cut': 1, 'co2': 1, 'emiss': 1, 'sinc': 1, 'plan': 1})
# Counter({'shade': 1, 'peopl': 1, 'throw': 1, 'green': 1, 'book': 1, 'make': 1, 'anxious': 1, 'arriv': 1, 'theater': 1, 'within': 1, 'hour': 1, 'hous': 1, 'go': 1, 'see': 1})
# Counter({'danielturnerptf': 1, 'radic': 1, 'environmentalist': 1, 'start': 1, 'give': 1, 'accur': 1, 'day': 1, 'forecast': 1, 'mayb': 1, 'american': 1, 'peopl': 1, 'stop': 1, 'laugh': 1})
# Counter({'joncoopertweet': 1, 'donald': 1, 'trump': 1, 'declar': 1, 'nation': 1, 'emerg': 1, 'build': 1, 'racist': 1, 'border': 1, 'wall': 1, 'wait': 1, 'futur': 1, 'democrat': 1, 'pres': 1})
# Counter({'rabbijil': 1, 'destroy': 1, 'everi': 1, 'good': 1, 'thing': 1, 'love': 1, 'money': 1, 'preciousearth': 1, 'plunder': 1, 'need': 1, 'protect': 1, 'amp': 1, 'sav': 1})
# Counter({'pokemon': 5, 'macintyrerath': 1, 'go': 1, 'sleep': 1, 'quit': 1, 'smoke': 1, 'cognit': 1, 'behavior': 1, 'therapi': 1, 'free': 1, 'access': 1, 'birth': 1, 'con': 1})
# Counter({'https': 2, 'co': 2, 'happi': 1, 'new': 1, 'week': 1, 'entrepreneur': 1, 'pleas': 1, 'rememb': 1, 'sign': 1, 'hkpmijmfbk': 1, 'get': 1, 'latest': 1, 'ecosystem': 1, 'news': 1, 'opportun': 1, 'inform': 1, 'tool': 1, 'resourc': 1, 'adgtywqhcz': 1})
# Counter({'need': 1, 'chill': 1, 'yes': 1})
# Counter({'senschum': 1, 'climat': 1, 'chang': 1, 'urgent': 1, 'crisi': 1, 'existenti': 1, 'threat': 1, 'countri': 1, 'planet': 1, 'requir': 1, 'singular': 1, 'focus': 1})
# Counter({'catscrivn': 1, 'fuck': 1, 'much': 1, 'bill': 1, 'nye': 1, 'beat': 1, 'ass': 1, 'start': 1, 'take': 1, 'climat': 1, 'chang': 1, 'serious': 1, 'https': 1, 'c': 1})
# Counter({'berniesand': 1, 'believ': 1, 'climat': 1, 'chang': 1, 'congress': 1})
# Counter({'climat': 2, 'chang': 2, 'year': 2, 'aoc': 1, 'liar': 1, 'say': 1, 'disagre': 1, 'approach': 1, 'organ': 1, 'place': 1, 'profit': 1, 'happen': 1, 'billion': 1, 'earth': 1, 'amp': 1, 'continu': 1})
# Counter({'mikehudema': 1, 'million': 1, 'german': 1, 'build': 1, 'solar': 1, 'panel': 1, 'roof': 1, 'solut': 1, 'climat': 1, 'crisi': 1, 'let': 1})
# Counter({'pklinkn': 1, 'midwestern': 1, 'root': 1, 'yale': 1, 'phd': 1, 'limit': 1, 'knowledg': 1, 'us': 1, 'senat': 1, 'https': 1, 'co': 1, '5k31l0mm7s': 1})
# Counter({'milanhartney': 1, 'becom': 1, 'renew': 1, 'energi': 1, 'sourc': 1, 'combat': 1, 'climat': 1, 'chang': 1, 'https': 1, 'co': 1, 'ai6j3aznz2': 1})
# Counter({'nairobiwilliamx': 1, 'yea': 1, 'climat': 1, 'chang': 1, 'bro': 1, 'https': 1, 'co': 1, 'utk45evtn6': 1})
# Counter({'aoc': 2, 'amypeikoff': 1, 'exampl': 1, 'realdonaldtrump': 1, 'pave': 1, 'way': 1, 'spokeswoman': 1, 'say': 1, 'leav': 1, 'climat': 1, 'chang': 1, 'god': 1})
# Counter({'newyork': 1, 'koch': 1, 'brother': 1, 'get': 1, 'rich': 1, 'use': 1, 'fortun': 1, 'buy': 1, 'american': 1, 'action': 1, 'climat': 1, 'chang': 1, 'https': 1})
# Counter({'environ': 1, 'switzerland': 1, 'plan': 1, 'reduc': 1, 'net': 1, 'carbon': 1, 'emiss': 1, 'zero': 1, 'meet': 1, 'target': 1, 'limit': 1, 'global': 1, 'warm': 1})
# Counter({'chrisyelland': 1, 'stun': 1, 'pictur': 1, 'mw': 1, 'kathu': 1, 'concentr': 1, 'solar': 1, 'power': 1, 'plant': 1, 'hour': 1, 'molten': 1, 'salt': 1, 'energi': 1, 'storag': 1, 'system': 1})
# Counter({'kendilaniannbc': 1, 'danger': 1, 'new': 1, 'hot': 1, 'zone': 1, 'spread': 1, 'around': 1, 'world': 1, 'https': 1, 'co': 1, 'lyxanc20l8': 1})
# Counter({'greenpeac': 2, 'girlsreallyrul': 1, 'patrick': 1, 'moor': 1, 'former': 1, 'presid': 1, 'canada': 1, 'co': 1, 'founder': 1, 'consult': 1, 'heartlan': 1})
# Counter({'lostdiva': 1, 'thousand': 1, 'scientist': 1, 'sign': 1, 'letter': 1, 'back': 1, 'youth': 1, 'climat': 1, 'chang': 1, 'protest': 1, 'https': 1, 'co': 1, '2apzvwdukd': 1})
# Counter({'kansasdem': 1, 'climat': 1, 'chang': 1, 'hit': 1, 'democrat': 1, 'republican': 1, 'alik': 1, 'need': 1, 'work': 1, 'togeth': 1, 'despit': 1, 'differ': 1, 'stop': 1, 'h': 1})
# Counter({'gregjamesbarton': 1, 'need': 1, 'loud': 1, 'activ': 1, 'combat': 1, 'climat': 1, 'chang': 1, 'skin': 1, 'cancer': 1, 'stop': 1, 'seek': 1, 'excus': 1, 'act': 1})
# Counter({'dumbhovan': 1, 'florida': 1, 'live': 1, 'feet': 1, 'abov': 1, 'sea': 1, 'level': 1, 'vote': 1, 'parti': 1, 'believ': 1, 'climat': 1, 'chang': 1, 'https': 1, 'co': 1, '3uyoyb': 1})
# Counter({'pbhushan1': 1, 'kudo': 1, 'govt': 1, 'cut': 1, 'gst': 1, 'registr': 1, 'amp': 1, 'tax': 1, 'provid': 1, 'incent': 1, 'peopl': 1, 'switch': 1, 'electr': 1, 'vehicl': 1})
# Counter({'drkiki': 1, 'eleph': 1, 'go': 1, 'fix': 1, 'us': 1, 'neither': 1, 'beauti': 1, 'david': 1, 'attenborough': 1, 'natur': 1, 'program': 1, 'need': 1, 'vote': 1, 'f': 1})
# Counter({'greenland': 1, 'rapid': 1, 'vanish': 1, 'glacier': 1, 'https': 1, 'co': 1, 'enac3a9bpo': 1, 'climat': 1, 'climatechang': 1})
# Counter({'downtown': 2, 'look': 1, 'predict': 1, 'sea': 1, 'level': 1, 'rise': 1, 'norfolk': 1, 'year': 1, 'follow': 1, 'bretthnew': 1, 'info': 1, 'tonight': 1, 'updat': 1, 'meet': 1})
# Counter({'ucsusa': 1, 'mattthia': 1, 'shellenbergermd': 1, 'almost': 1, 'scenario': 1, 'limit': 1, 'climat': 1, 'chang': 1, 'reli': 1, 'massiv': 1, 'amount': 1, 'carbon': 1, 'captur': 1, 'technic': 1, 'feasibl': 1, 'still': 1, 'total': 1, 'undemonstr': 1, 'effort': 1, 'sinc': 1, 'push': 1, 'end': 1, 'complet': 1, 'expens': 1, 'failur': 1, 'onli': 1, 'realist': 1, 'altern': 1, 'technolog': 1, 'nuclear': 1})
# Counter({'disast': 2, 'articl': 1, 'noaa': 1, 'billion': 1, 'chelseaeharvey': 1, 'eenewsupd': 1, 'one': 1, 'best': 1, 'seen': 1, 'grappl': 1, 'honest': 1, 'challeng': 1, 'link': 1, 'trend': 1, 'climat': 1, 'chang': 1, 'attribut': 1, 'support': 1, 'ipcc': 1, 'nca': 1, 'quot': 1, 'follow': 1})
# Counter({'problem': 2, 'pastorabharri': 1, 'nowthisnew': 1, 'climat': 1, 'sin': 1, 'https': 1, 'co': 1, 'g4ochjxjhu': 1})
# Counter({'kamalaharri': 1, 'climat': 1, 'chang': 1, 'ever': 1, 'grow': 1, 'threat': 1, 'public': 1, 'health': 1, 'countless': 1, 'scientist': 1, 'warn': 1, 'us': 1, 'time': 1, 'act': 1})
# Counter({'aoc': 1, 'american': 1, 'die': 1, 'hurrican': 1, 'maría': 1, 'midwest': 1, 'drown': 1, 'speak': 1, '100s': 1, 'flint': 1, 'famili': 1, 'pump': 1, 'w': 1, 'poison': 1, 'water': 1})
# Counter({'acosta': 1, 'juli': 1, 'hottest': 1, 'month': 1, 'earth': 1, 'planet': 1, 'miss': 1, 'million': 1, 'squar': 1, 'mile': 1, 'sea': 1, 'ice': 1, 'via': 1, 'washington': 1, 'post': 1, 'https': 1})
# Counter({'inlighteng': 2, 'follow': 1, 'monday': 1, 'friday': 1, '7am': 1, 'est': 1, 'wake': 1, 'campaign': 1, 'bring': 1, 'awar': 1, 'issu': 1, 'clima': 1})
# Counter({'whoainterest': 1, 'solar': 1, 'eclips': 1, 'record': 1, 'south': 1, 'america': 1, 'morn': 1, 'https': 1, 'co': 1, 'le6dszkwb5': 1})
# Counter({'savannahmaroney': 1, 'offici': 1, 'onli': 1, 'month': 1, 'revers': 1, 'climat': 1, 'chang': 1, 'befor': 1, 'irrevers': 1, 'tweet': 1, 'gonna': 1, 'get': 1})
# Counter({'go': 2, 'craigbennett3': 1, 'afraid': 1, 'prime': 1, 'minist': 1, 'give': 1, 'ahead': 1, '3rd': 1, 'runway': 1, 'heathrow': 1, 'frack': 1, 'allow': 1})
# Counter({'infra': 4, 'narendramodi': 1, 'india': 1, 'franc': 1, 'allianc': 1, 'robust': 1, 'togeth': 1, 'boost': 1, 'solar': 1, 'social': 1, 'technic': 1})
# Counter({'realli': 1, 'interest': 1})
# Counter({'jhw229': 1, 'polar': 1, 'bear': 1, 'start': 1, 'practic': 1, 'cannib': 1, 'mother': 1, 'eat': 1, 'cub': 1, 'becaus': 1, 'drastic': 1, 'climat': 1, 'chang': 1})
# Counter({'un': 2, 'peopl': 2, 'feed': 1, '80m': 1, 'suppli': 1, 'vaccin': 1, 'children': 1, 'protect': 1, 'forc': 1, 'flee': 1, 'tackl': 1, 'climat': 1, 'chang': 1, 'keep': 1, 'peac': 1})
# Counter({'climat': 2, 'walrus': 2, 'terrenceedward': 1, 'sad': 1, 'realiti': 1, 'chang': 1, 'ice': 1, 'place': 1, 'go': 1, 'ourplanet': 1, 'climatechang': 1})
# Counter({'womensart1': 1, 'banner': 1, 'greta': 1, 'thunberg': 1, 'year': 1, 'old': 1, 'swedish': 1, 'climat': 1, 'activist': 1, 'known': 1, 'start': 1, 'first': 1, 'schoolstrike4clim': 1, 'rai': 1})
# Counter({'repadamschiff': 1, 'tri': 1, 'trump': 1, 'administr': 1, 'might': 1, 'buri': 1, 'studi': 1, 'friday': 1, 'thanksgiv': 1, 'effect': 1, 'climat': 1, 'chang': 1})
# Counter({'fslr': 3, 'first': 2, 'solar': 2, 'inc': 2, 'uafr': 2, 'base': 2, 'https': 2, 'co': 2, 'embed': 1, 'expect': 1, 'analysi': 1, 'usa': 1, 'current': 1, 'trade': 1, 'discount': 1, 'uniform': 1, 'asset': 1, '6x': 1, 'p': 1, 'b': 1, 'level': 1, 'market': 1, 'relat': 1, 'mute': 1, 'xi2zhi8xsl': 1, 'kvksfsx0pn': 1})
# Counter({'benparfittccpa': 1, 'hmm': 1, 'drive': 1, 'electr': 1, 'car': 1, 'timefram': 1, 'bc': 1, 'drill': 1, 'frack': 1, 'liquefi': 1, 'export': 1, 'nat': 1})
# Counter({'believ': 2, 'danrath': 1, 'thought': 1, 'consid': 1, 'margin': 1, 'santa': 1, 'age': 1, 'climat': 1, 'chang': 1})
# Counter({'believ': 3, 'cfiguer': 1, 'need': 1, 'remov': 1, 'verb': 1, 'climat': 1, 'chang': 1, 'graviti': 1, 'earth': 1})
# Counter({'drwaheeduddin': 1, 'barbarajdurkin': 1, 'hupric': 1, 'oldfosil66': 1, 'piers_corbyn': 1, 'jamesb_bkk': 1, 'gillesnfio': 1, 'friendsosci': 1, 'jwspri': 1, 'jaggermickoz': 1, '3ghtw': 1})
# Counter({'cut': 2, 'emiss': 2, 'eroston': 1, 'everybodi': 1, 'wait': 1, 'long': 1, 'harder': 1, 'adapt': 1, 'chang': 1, 'alreadi': 1, 'arriv': 1})
# Counter({'markfollman': 1, 'trump': 1, 'smack': 1, 'blue': 1, 'wall': 1, 'https': 1, 'co': 1, 'o3cokcrjr': 1})
# Counter({'current': 1, 'weather': 1, 'f': 1, 'c': 1, 'overcast': 1, 'wind': 1, 'nne': 1, '6mph': 1, 'precipit': 1, 'mm': 1, 'visibl': 1, '0mile': 1, 'humid': 1, 'solar': 1, 'radiat': 1, 'uv': 1, 'xoxo': 1, 'vegan': 1, 'cyborg': 1, 'mar': 1, 'https': 1, 'co': 1, 'ek2rh3sfzu': 1})
# Counter({'quancyclayborn': 1, 'along': 1, 'voter': 1, 'suppress': 1, 'gop': 1, 'trump': 1, 'biggest': 1, 'problem': 1, 'face': 1, 'world': 1, 'https': 1, 'co': 1, 'gs6mv': 1})
# Counter({'less': 2, 'make': 2, 'aoc': 1, 'think': 1, 'one': 1, 'pleas': 1, 'respond': 1, 'quick': 1, 'end': 1, 'world': 1, 'year': 1, 'away': 1, 'mayb': 1, 'batteri': 1, 'pack': 1, 'solar': 1, 'panel': 1, 'electr': 1, 'vehicl': 1, 'happen': 1, 'get': 1, 'rid': 1, 'oil': 1, 'product': 1, 'reli': 1, 'crude': 1})
# Counter({'govt': 2, 'khan': 2, 'darshanpathak': 1, 'place': 1, 'alwar': 1, 'rajasthan': 1, 'bjp': 1, 'replac': 1, 'congress': 1, 'pehlu': 1, 'akbar': 1, 'turn': 1, 'youth': 1, 'sageer': 1, 'kha': 1})
# Counter({'mrwyattearpla': 1, 'hey': 1, 'left': 1, 'pizza': 1, 'relat': 1, 'handkerchief': 1, 'place': 1, 'spirit': 1, 'cook': 1, 'wanna': 1, 'come': 1, 'pick': 1})
# Counter({'mikepouzi': 1, 'america': 1, 'like': 1, 'mass': 1, 'shoot': 1, 'systemat': 1, 'racism': 1, 'kid': 1, 'cage': 1, 'elect': 1, 'hack': 1, 'global': 1, 'warm': 1})
# Counter({'allentien': 1, 'much': 1, 'pharma': 1, 'propaganda': 1, 'lot': 1, 'neurosci': 1, 'brain': 1, 'disord': 1, 'innov': 1, 'drug': 1, 'develop': 1, 'mention': 1, 'social': 1, 'structur': 1, 'polit': 1, 'determin': 1, 'mental': 1, 'health': 1, 'noth': 1, 'poverti': 1, 'displac': 1, 'food': 1, 'insecur': 1, 'war': 1, 'climat': 1, 'chang': 1})
# Counter({'greenpeac': 1, 'thousand': 1, 'barrel': 1, 'oil': 1, 'leak': 1, 'java': 1, 'sea': 1, 'indonesia': 1, 'month': 1, 'affect': 1, 'ecosystem': 1, 'amp': 1, 'live': 1})
# Counter({'adnocgroup': 1, 'adnoc': 1, 'ambiti': 1, 'year': 1, 'plan': 1, 'six': 1, 'fold': 1, 'increas': 1, 'co2': 1, 'captur': 1, 'safe': 1, 'underground': 1, 'storag': 1, 'util': 1, 'ccus': 1})
# Counter({'https': 3, 'co': 3, 'solar': 1, 'flare': 1, 'strike': 1, 'earth': 1, 'apocalyps': 1, 'begin': 1, 'prepar': 1, 'gtabslkyvb': 1, 'nnib3y6flj': 1, 'thrill': 1, 'new': 1, 'year': 1, 'apocalypt': 1, 'sciencefict': 1, 'dystopia': 1, 'free': 1, 'kindl': 1, 'unlimit': 1, '3ppupkapdd': 1})
# Counter({'prisonplanet': 1, 'barack': 1, 'obama': 1, 'princ': 1, 'harri': 1, 'leonardo': 1, 'dicaprio': 1, 'kati': 1, 'perri': 1, 'amp': 1, 'hundr': 1, 'flown': 1, 'itali': 1, 'discuss': 1, 'global': 1})
# Counter({'sethabramson': 1, 'let': 1, 'fix': 1, 'syntax': 1, 'headlin': 1, 'hill': 1, 'sarah': 1, 'sander': 1, 'dismiss': 1, 'base': 1, 'fact': 1, 'govern': 1, 'report': 1})
# Counter({'co2': 2, 'longnow': 1, 'massiv': 1, 'reforest': 1, 'effort': 1, 'could': 1, 'captur': 1, 'gigaton': 1, 'next': 1, 'year': 1, 'two': 1, 'third': 1, 'human': 1, 'h': 1})
# Counter({'tax': 2, '1eggwhit': 1, 'burger': 1, 'exact': 1, 'modern': 1, 'equival': 1, 'tea': 1, 'riski': 1, 'busi': 1, 'power': 1, 'https': 1, 'co': 1, 'haqbtawm7m': 1})
# Counter({'chang': 2, 'becaus': 2, 'eyesonq': 1, 'nasa': 1, 'admit': 1, 'climat': 1, 'occur': 1, 'earth': 1, 'solar': 1, 'orbit': 1, 'suv': 1, 'fossil': 1, 'fuel': 1, 'htt': 1})
# Counter({'https': 4, 'co': 4, 'poland': 1, 'slash': 1, 'vat': 1, 'residenti': 1, 'solar': 1, 'gwayq1xwcg': 1, '8m9v6lvg2a': 1, 'ianjghoiqi': 1, '9vcbtjjnls': 1})
# Counter({'merv': 1, 'leftnoteasi': 1, 'acmurthi': 1, 'ratio': 1, 'differ': 1, 'hadoop': 1, 'subproject': 1, 'sinc': 1, 'month': 1, 'number': 1, 'resolv': 1, 'issu': 1, 'jira': 1, 'yes': 1, 'mapreduc': 1, 'declin': 1, 'ozon': 1, 'hdfs': 1, 'strong': 1, 'https': 1, 'co': 1, 'twhpvbqsqd': 1})
# Counter({'billmckibben': 1, 'keep': 1, 'powder': 1, 'dri': 1, 'wait': 1, 'moment': 1, 'climat': 1, 'fight': 1, 'realli': 1, 'need': 1, 'right': 1})
# Counter({'bellwhitworth': 1, 'anyon': 1, 'told': 1, 'dimpl': 1, 'amp': 1, 'druggi': 1, 'https': 1, 'co': 1, '6ymjamgf0k': 1})
# Counter({'pauledawson': 1, 'main': 1, 'reason': 1, 'peopl': 1, 'move': 1, 'becaus': 1, 'anyth': 1, 'eat': 1, 'strong': 1, 'link': 1, 'climat': 1, 'chang': 1})
# Counter({'popsci': 1, 'irrefut': 1, 'piec': 1, 'evid': 1, 'prove': 1, 'climat': 1, 'chang': 1, 'real': 1, 'https': 1, 'co': 1, 'key1pt3spq': 1})
# Counter({'bora_ecosystem': 1, 'decentr': 1, 'entertain': 1, 'platform': 1, 'provid': 1, 'incent': 1, 'base': 1, 'digit': 1, 'content': 1, 'distribut': 1, 'use': 1, 'blockchain': 1, 'join': 1, 'bounti': 1, 'program': 1, 'earn': 1, 'bora': 1, 'token': 1, 'offici': 1, 'list': 1, 'coinsup': 1, 'https': 1, 'co': 1, 'qqtrnnswl1': 1, 'boraecosystem': 1, 'borabounti': 1})
# Counter({'carolina': 2, 'tracyjan': 1, 'dorian': 1, 'barrel': 1, 'toward': 1, 'stori': 1, 'north': 1, 'hurrican': 1, 'scientist': 1, 'could': 1})
# Counter({'aseitzwald': 1, 'jay': 1, 'insle': 1, 'threw': 1, 'gauntlet': 1, 'climat': 1, 'filibust': 1, 'today': 1, 'take': 1, 'shot': 1, '2020er': 1, 'told': 1, 'stage': 1, 'yo': 1})
# Counter({'notroost': 1, 'america': 1, 'teen': 1, 'keep': 1, 'get': 1, 'unhappi': 1, 'near': 1, 'percent': 1, 'american': 1, 'teenag': 1, 'experienc': 1, 'major': 1, 'depress': 1})
# Counter({'maplethorpej': 1, 'ericholthaus': 1, 'rise': 1, 'sea': 1, 'bad': 1, 'enough': 1, 'account': 1, 'feedback': 1, 'effect': 1, 'take': 1, 'place': 1})
# Counter({'solar': 2, 'siyooluvr': 1, 'korea': 1, 'hwasa': 1, 'stop': 1, 'wear': 1, 'reveal': 1, 'cloth': 1, 'stage': 1, 'https': 1, 'co': 1, 'kexredf6cu': 1})
# Counter({'trisresist': 1, 'statu': 1, 'locat': 1, 'berlin': 1, 'entitl': 1, 'politician': 1, 'discuss': 1, 'global': 1, 'warm': 1, 'speak': 1, 'volum': 1, 'https': 1, 'co': 1, '632yhja': 1})
# Counter({'global': 1, 'warm': 1, 'climat': 1, 'chang': 1, 'disast': 1, 'convey': 1, 'environment': 1, 'predica': 1, 'https': 1, 'co': 1, 'gtw6wtyfil': 1})
# Counter({'mooswithsun': 1, 'whi': 1, 'matter': 1, 'kpoppi': 1, 'say': 1, 'big3': 1, 'privileg': 1, 'real': 1, 'fact': 1, 'know': 1, 'name': 1, 'rooki': 1, 'group': 1, 'arou': 1})
# Counter({'wire': 1, 'scam': 1, 'https': 1, 'co': 1, 'zz4yj3mrmi': 1})
# Counter({'virendraahd': 1, 'green_mentor': 1, 'climat': 1, 'chang': 1, 'https': 1, 'co': 1, 'rrfld11p0p': 1})
# Counter({'kingtheloni': 1, 'go': 1, 'https': 1, 'co': 1, '5lwplae4cc': 1})
# Counter({'will_bunch': 1, 'fascin': 1, 'age': 1, 'walk': 1, 'half': 1, 'mile': 1, 'everi': 1, 'day': 1, 'elementari': 1, 'school': 1, 'shop': 1, 'center': 1})
# Counter({'826maureen': 1, 'bill': 1, 'shorten': 1, 'refus': 1, 'outlin': 1, 'cost': 1, 'labor': 1, 'climat': 1, 'chang': 1, 'polici': 1, 'mean': 1, 'onli': 1, 'one': 1, 'two': 1, 'thing': 1})
# Counter({'media': 2, 'balaji': 1, 'legaci': 1, 'subset': 1, 'social': 1, 'big': 1, 'also': 1, 'anoth': 1, 'entiti': 1, 'post': 1, 'content': 1, 'onlin': 1, 'tradit': 1, 'bank': 1})
# Counter({'ofb2020': 1, 'environment': 1, 'displac': 1, 'huge': 1, 'issu': 1, 'veri': 1, 'near': 1, 'futur': 1, 'exhibit': 1, 'sea': 1, 'level': 1, 'south': 1, 'carolina': 1, 'coast': 1})
# Counter({'softwaredoug': 1, 'elasticsearch': 1, 'becom': 1, 'contributor': 1, 'bewar': 1, 'ecosystem': 1, 'jccq': 1, 'provid': 1, 'construct': 1, 'idea': 1, 'ensur': 1, 'good': 1, 'con': 1})
# Counter({'sethmacfarlan': 1, 'presid': 1, 'comment': 1, 'read': 1, 'like': 1, 'cat': 1, 'walk': 1, 'across': 1, 'keyboard': 1, 'scientist': 1, 'compil': 1, 'peer': 1, 'review': 1, 'evid': 1, 'natio': 1})
# Counter({'moeritherium_': 1, 'worri': 1, 'pay': 1, 'enough': 1, 'attent': 1, 'https': 1, 'co': 1, 'sbr12coaah': 1})
# Counter({'rbw_mamamoo': 1, '솔라': 1, '4season': 1, 'project': 1, 'white_wind': 1, 'concept': 1, 'photo': 1, 'thu': 1, 'pm6': 1, 'kst': 1, 'mamamoo': 1, 'solar': 1, 'comeback': 1, 'https': 1})
# Counter({'ocasio2018': 1, 'thing': 1, 'conserv': 1, 'pundit': 1, 'name': 1, 'call': 1, 'echo': 1, 'conspiraci': 1, 'theori': 1, 'mock': 1, 'intellig': 1, 'appear': 1, 'stori': 1, 'ident': 1})
# Counter({'kurtlass1': 1, 'natur': 1, 'alreadi': 1, 'develop': 1, 'fulli': 1, 'function': 1, 'biolog': 1, 'ferment': 1, 'bioreactor': 1, 'convers': 1, 'ined': 1, 'solar': 1, 'pow': 1})
# Counter({'ikebarinholtz': 1, 'never': 1, 'get': 1, 'fact': 1, 'presid': 1, 'stupidest': 1, 'person': 1, 'countri': 1, 'https': 1, 'co': 1, 'xbcjoygj5g': 1})
# Counter({'climat': 2, 'walrus': 2, 'terrenceedward': 1, 'sad': 1, 'realiti': 1, 'chang': 1, 'ice': 1, 'place': 1, 'go': 1, 'ourplanet': 1, 'climatechang': 1})
# Counter({'would': 2, 'pauledawson': 1, 'exxon': 1, 'predict': 1, 'co2': 1, 'level': 1, 'reach': 1, '560ppm': 1, 'push': 1, 'planet': 1, 'averag': 1, 'temperatur': 1, 'b': 1})
# Counter({'climat': 1, 'chang': 1, 'expert': 1, 'sentenc': 1, 'month': 1, 'fraud': 1, 'say': 1, 'lie': 1, 'rush': 1, 'https': 1, 'co': 1, 'ndw2e8nxfh': 1, 'via': 1, 'nbcnew': 1})
# Counter({'burn': 2, 'paugasol': 1, 'amazon': 1, 'onli': 1, 'doe': 1, 'planet': 1, 'largest': 1, 'lung': 1, 'ecosystem': 1, 'thousand': 1, 'anim': 1, 'speci': 1, 'al': 1})
# Counter({'stop': 2, 'warm': 2, 'billmckibben': 1, 'new': 1, 'studi': 1, 'emiss': 1, 'immedi': 1, 'arctic': 1, 'still': 1, '5c': 1, '9f': 1, 'centuri': 1, 'end': 1, 'global': 1})
# Counter({'mariannevelvart': 1, 'given': 1, 'bod': 1, 'anyon': 1, 'wish': 1, 'answer': 1, 'thank': 1, 'either': 1, 'way': 1, 'https': 1, 'co': 1, 'dt1dmlbhya': 1})
# Counter({'matthewjdowd': 1, 'gatewaypundit': 1, 'aoc': 1, 'jim': 1, 'would': 1, 'suggest': 1, 'read': 1, 'solar': 1, 'heat': 1, 'work': 1})
# Counter({'ios48101161': 1, 'moomoo': 1, 'ask': 1, 'solar': 1, 'tri': 1, 'get': 1, 'ticket': 1, 'concert': 1, 'compani': 1, 'told': 1, 'becaus': 1})
# Counter({'sign': 2, 'lugey6': 1, 'chant': 1, 'jeremi': 1, 'corbyn': 1, 'amp': 1, 'hold': 1, 'say': 1, 'tori': 1, 'incred': 1, 'worri': 1, 'school': 1, 'system': 1, 'th': 1})
# Counter({'discoclit': 1, 'whi': 1, 'doe': 1, 'sound': 1, 'like': 1, 'lana': 1, 'del': 1, 'rey': 1, 'lyric': 1, 'https': 1, 'co': 1, 'w49ocsvrdc': 1})
# Counter({'eleg': 1, 'demonstr': 1, 'climat': 1, 'chang': 1, 'harm': 1, 'arctic': 1, 'sea': 1, 'life': 1, 'stori': 1, 'alway': 1, 'give': 1, 'agita': 1, 'drink': 1, 'chocol': 1, 'milk': 1, 'right': 1, 'away': 1, 'https': 1, 'co': 1, 'agihspaye0': 1})
# Counter({'pleas': 1, 'sign': 1, 'amp': 1, 'petit': 1, 'mean': 1, 'lot': 1, 'https': 1, 'co': 1, 'k6jvpcwao1': 1, 'via': 1, '38_degre': 1})
# Counter({'front': 1, 'side': 1, 'say': 1, 'energi': 1, 'observ': 1, 'mayb': 1, 'measur': 1, 'solar': 1, 'power': 1})
# Counter({'belcherjody1': 1, 'liter': 1, 'whirlwind': 1, 'tour': 1, 'human': 1, 'windsock': 1, 'answer': 1, 'climat': 1, 'chang': 1, 'never': 1, 'knew': 1, 'minor': 1, 'e': 1})
# Counter({'ecosensenow': 1, 'read': 1, 'water': 1, 'vapour': 1, 'follow': 1, 'link': 1, 'year': 1, 'ago': 1, 'https': 1, 'co': 1, 'nejb9apg6z': 1})
# Counter({'glennhowerton': 1, 'eat': 1, 'plant': 1, 'base': 1, 'diet': 1, 'easiest': 1, 'thing': 1, 'person': 1, 'lessen': 1, 'man': 1, 'impact': 1, 'climat': 1, 'chang': 1})
# Counter({'jillwinebank': 1, 'letter': 1, 'liz': 1, 'holtzman': 1, 'even': 1, 'relev': 1, 'reject': 1, 'bahamian': 1, 'refuge': 1, 'flee': 1, 'devast': 1})
# Counter({'thought': 1, 'waterworld': 1, 'mediocr': 1, 'kevin': 1, 'costner': 1, 'movi': 1, 'look': 1, 'like': 1, 'world': 1, 'live': 1, 'climatecrisi': 1, 'https': 1, 'co': 1, 'qtbayxkqil': 1})
# Counter({'e': 2, 'xrbayarea': 1, 'govern': 1, 'fulli': 1, 'control': 1, 'fossil': 1, 'fuel': 1, 'industri': 1, 'go': 1, 'tri': 1, 'v': 1, 'r': 1, 'h': 1, 'n': 1, 'g': 1, 'avoid': 1, 'act': 1})
# Counter({'indivisibleteam': 1, 'extrem': 1, 'weather': 1, 'like': 1, 'saw': 1, 'week': 1, 'result': 1, 'climat': 1, 'chang': 1, 'tell': 1, 'member': 1, 'congr': 1})
# Counter({'man': 1, 'want': 1, 'mother': 1, 'natur': 1, 'end': 1, 'well': 1})
# Counter({'luckyheronsay': 1, 'need': 1, 'tweet': 1, 'like': 1, 'lot': 1, 'peopl': 1, 'jc4pm2019': 1, 'https': 1, 'co': 1, 'cq1gyqu1d': 1})
# Counter({'berni': 2, 'sander': 1, 'slam': 1, 'trump': 1, 'tweet': 1, 'deport': 1, 'instead': 1, 'talk': 1, 'climat': 1, 'chang': 1, 'come': 1, 'get': 1, 'pot': 1, 'https': 1, 'co': 1, 'tmcg990nil': 1, 'via': 1, 'weaselzipp': 1})
# Counter({'donaldjtrumpjr': 1, 'make': 1, 'mistak': 1, 'anyon': 1, 'think': 1, 'anyway': 1, 'watch': 1, 'https': 1, 'co': 1, 'cxbept88yz': 1})
# Counter({'stpiindia': 2, 'dg': 1, 'dr': 1, 'omkar_raii': 1, 'one': 1, 'key': 1, 'speaker': 1, 'resurgentindiayuvaconclave2019': 1, 'share': 1, 'thought': 1, 'entr': 1})
# Counter({'aoc': 1, 'like': 1, 'mani': 1, 'women': 1, 'work': 1, 'peopl': 1, 'occasion': 1, 'suffer': 1, 'impostor': 1, 'syndrom': 1, 'small': 1, 'moment': 1, 'especi': 1, 'hard': 1, 'day': 1})
# Counter({'ewarren': 1, 'last': 1, 'month': 1, 'hottest': 1, 'june': 1, 'record': 1, 'flood': 1, 'extrem': 1, 'weather': 1, 'devast': 1, 'communiti': 1, 'caus': 1, 'billion': 1, 'dol': 1})
# Counter({'love_the_donald': 1, 'appear': 1, 'gov': 1, 'brown': 1, 'intent': 1, 'let': 1, 'hundr': 1, 'californian': 1, 'die': 1, 'fire': 1, 'alterior': 1, 'motiv': 1})
# Counter({'leannewood': 1, 'ukip': 1, 'aka': 1, 'farright': 1, 'complet': 1, 'joke': 1, 'idea': 1, 'poverti': 1, 'world': 1, 'poor': 1, 'affect': 1})
# Counter({'rodeccl': 1, 'climat': 1, 'chang': 1, 'great': 1, 'threat': 1, 'planet': 1, 'may': 1, 'want': 1, 'actual': 1, 'get': 1, 'india': 1, 'china': 1, 'agre': 1})
# Counter({'demon': 2, 'nprpolit': 1, 'william': 1, 'happer': 1, 'label': 1, 'climat': 1, 'scienc': 1, 'cult': 1, 'onc': 1, 'said': 1, 'carbon': 1, 'dioxid': 1, 'like': 1})
# Counter({'stealingisfunni': 1, 'befor': 1, 'fuck': 1, 'love': 1, 'global': 1, 'warm': 1, 'see': 1, 'pain': 1, 'confus': 1, 'lighten': 1, 'mcqueen': 1, 'eye': 1})
# Counter({'wind': 2, 'solar': 2, 'ecosensenow': 1, 'fact': 1, 'technolog': 1, 'made': 1, 'energi': 1, 'would': 1, 'end': 1, 'insan': 1})
# Counter({'climat': 2, 'walrus': 2, 'terrenceedward': 1, 'sad': 1, 'realiti': 1, 'chang': 1, 'ice': 1, 'place': 1, 'go': 1, 'ourplanet': 1, 'climatechang': 1})
# Counter({'_man_like_': 1, 'sophieblack2016': 1, 'eu': 1, 'tariff': 1, 'chines': 1, 'solar': 1, 'cell': 1})
# Counter({'stclairashley': 1, 'sorri': 1, 'go': 1, 'take': 1, 'scienc': 1, 'lesson': 1, 'woman': 1, 'flunk': 1, 'dna': 1, 'test': 1, 'https': 1, 'co': 1, '9hppt04ttr': 1})
# Counter({'highway': 2, 'cmo': 1, 'happi': 1, 'petrol': 1, 'diesel': 1, 'price': 1, 'hike': 1, 'nsitharaman': 1, 'let': 1, 'understand': 1, 'know': 1, 'whi': 1, 'narendramodi': 1, 'nitin_gadkari': 1, 'electr': 1, 'lt': 1, 'solar': 1, 'street': 1, 'gt': 1, 'trust': 1, 'make': 1, 'bombay': 1, 'goa': 1, 'best': 1, 'world': 1, 'https': 1, 'co': 1, 'dseimrayhu': 1})
# Counter({'year': 2, 'lilnasx': 1, 'stuart': 1, 'littl': 1, 'presid': 1, 'world': 1, 'war': 1, 'led': 1, 'shrek': 1, 'amp': 1, 'thano': 1, 'end': 1, 'old': 1, 'town': 1, 'road': 1, 'reach': 1})
# Counter({'richardtuffin': 1, 'australia': 1, 'treat': 1, 'closest': 1, 'neighbour': 1, 'refus': 1, 'take': 1, 'real': 1, 'action': 1, 'climat': 1, 'chang': 1, 'th': 1})
# Counter({'lexiiscottt': 1, 'love': 1, 'https': 1, 'co': 1, 'npov0x4zw1': 1})
# Counter({'lt': 2, 'paulvixi': 1, 'interdepend': 1, 'within': 1, 'societi': 1, 'today': 1, 'absolut': 1, 'center': 1, 'internet': 1, 'beyond': 1, 'depend': 1, 'except': 1, 'climat': 1})
# Counter({'twitter': 1, 'celeb': 1, 'make': 1, 'rw': 1, 'ecosystem': 1, 'https': 1, 'co': 1, 'ifffn2h6lq': 1})
# Counter({'hwasa': 4, 'talent': 2, 'solar': 2, 'byulsepiphani': 1, 'nah': 1, 'fck': 1, 'go': 1, 'back': 1, 'sleep': 1, 'pretti': 1, 'kind': 1, 'pure': 1, 'goddess': 1})
# Counter({'minut': 2, 'blkahn': 1, 'tv': 1, 'news': 1, 'devot': 1, 'press': 1, 'issu': 1, 'face': 1, 'human': 1, 'came': 1, 'dure': 1, 'one': 1, 'e': 1})
# Counter({'https': 2, 'co': 2, 'noaaclim': 1, 'winter': 1, 'storm': 1, 'prove': 1, 'global': 1, 'warm': 1, 'happen': 1, 'ldqfq4jh9n': 1, 'ndmld637cb': 1})
# Counter({'enough': 3, 'thehil': 1, 'sen': 1, 'martin': 1, 'heinrich': 1, 'climat': 1, 'chang': 1, 'say': 1, 'denial': 1, 'delay': 1, 'fake': 1})
# Counter({'dunno': 1, 'seem': 1, 'bad': 1})
# Counter({'planet': 2, 'dawn_macc': 1, 'berniesand': 1, 'pollut': 1, 'fulli': 1, 'know': 1, 'damag': 1, 'caus': 1, 'suppress': 1, 'intern': 1, 'studi': 1, 'said': 1, 'global': 1, 'climat': 1, 'chang': 1, 'real': 1, 'knew': 1, 'year': 1, 'threaten': 1, 'speci': 1, 'amp': 1, 'civil': 1, 'product': 1, 'trump': 1, 'sander': 1, 'riiiight': 1})
# Counter({'cryptoproglob': 1, 'https': 1, 'co': 1, 'qmyvqnhuk': 1, 'booth': 1, 'blockshow': 1, 'asia': 1, 'cointelegraph': 1, 'empow': 1, 'blockchain': 1, 'revolutiontoward': 1, 'safer': 1})
# Counter({'aoc': 1, 'gop': 1, 'senat': 1, 'use': 1, 'congression': 1, 'allow': 1, 'print': 1, 'aquaman': 1, 'poster': 1, 'themselv': 1, 'argu': 1, 'greennewd': 1, 'save': 1})
# Counter({'hopeworldian': 1, 'next': 1, 'week': 1, 'blame': 1, 'bts': 1, 'global': 1, 'warm': 1, 'pleas': 1, 'stay': 1, 'tune': 1})
# Counter({'stevesgoddard': 1, 'mlbinwa': 1, 'iancharboneau': 1, 'bigskyrad': 1, 'llviola': 1, 'sylviad32911201': 1, 'david_hanselman': 1, 'ralphrotten0': 1, 'geraldkutney': 1, 'waltkostrzew': 1})
# Counter({'amp': 2, 'nobamadotcom': 1, 'expert': 1, 'left': 1, 'aoc': 1, 'boston': 1, 'univers': 1, 'colleg': 1, 'art': 1, 'scienc': 1, 'major': 1, 'int': 1, 'l': 1, 'relat': 1, 'econom': 1})
# Counter({'mollymep': 1, 'great': 1, 'see': 1, 'channel4new': 1, 'take': 1, 'extinctionr': 1, 'action': 1, 'central': 1, 'london': 1, 'serious': 1, 'noth': 1, 'less': 1, 'struggl': 1, 'fo': 1})
# Counter({'produc': 3, 'capac': 2, 'total': 2, 'generat': 2, 'moment': 1, 'alberta': 1, 'electr': 1, 'fossil': 1, 'fuel': 1, 'wind': 1, 'solar': 1, 'time': 1, 'export': 1, 'mw': 1})
# Counter({'earth': 1, 'onli': 1, 'inhabit': 1, 'planet': 1, 'past': 1, 'time': 1, 'govern': 1, 'mobil': 1, 'strong': 1, 'effect': 1, 'climat': 1, 'chang': 1, 'mitig': 1, 'action': 1})
# Counter({'tron': 2, 'dapp': 2, 'justinsuntron': 1, 'order': 1, 'let': 1, 'tronic': 1, 'know': 1, 'process': 1, 'made': 1, 'week': 1, 'report': 1, 'welcom': 1, 'develop': 1})
# Counter({'sbsnew': 1, 'year': 1, 'old': 1, 'messag': 1, 'scott': 1, 'morrison': 1, 'ridicul': 1, 'respons': 1, 'young': 1, 'aussi': 1, 'skip': 1, 'school': 1, 'friday': 1})
# Counter({'fantasi': 1, 'acceler': 1, 'sea': 1, 'level': 1, 'rise': 1, 'got': 1, 'hose': 1, 'https': 1, 'co': 1, 'njgxriqe4': 1, 'via': 1, 'wattsupwiththat': 1})
# Counter({'prepar': 1, 'food': 1, 'shortag': 1, 'anthropogen': 1, 'climat': 1, 'chang': 1, 'weather': 1, 'effect': 1, 'grandsolarminimum': 1, 'https': 1, 'co': 1, 'iv4ccqexc9': 1})
# Counter({'jerrykmii': 1, 'mattjcan': 1, 'discuss': 1, 'contribut': 1, 'campfir': 1, 'global': 1, 'warm': 1, 'good': 1, 'time': 1})
# Counter({'crushcuitur': 1, 'scari': 1, 'know': 1, 'probabl': 1, 'wont': 1, 'aliv': 1, 'kid': 1, 'grow': 1, 'old': 1, 'togeth': 1, 'someon': 1, 'becaus': 1, 'fact': 1})
# Counter({'gabriellechloe': 1, 'solar': 1, 'eclips': 1, 'beauti': 1, 'https': 1, 'co': 1, 'lfwfxcuuj7': 1})
# Counter({'ocasio2018': 1, 'peopl': 1, 'go': 1, 'die': 1, 'start': 1, 'address': 1, 'climat': 1, 'chang': 1, 'asap': 1, 'enough': 1, 'think': 1, 'import': 1, 'mu': 1})
# Counter({'year': 2, 'mcannonbrook': 1, 'emiss': 1, 'gone': 1, 'everi': 1, 'long': 1, 'term': 1, 'trend': 1, 'clear': 1, 'focuss': 1, 'good': 1, 'news': 1, 'talk': 1})
# Counter({'scholar': 2, 'today': 1, 'showcas': 1, 'present': 1, 'number': 1, 'interest': 1, 'topic': 1, 'includ': 1, 'preserv': 1, 'discard': 1, 'cell': 1, 'phone': 1, 'climat': 1, 'chang': 1, 'proud': 1, 'msu': 1, 'upwardbound': 1, 'scholarshowcas': 1, 'https': 1, 'co': 1, 'jubqigtvox': 1})
# ...
# Counter({'gavinnewsom': 1, 'trump': 1, 'admin': 1, 'tri': 1, 'buri': 1, 'report': 1, 'evid': 1, 'climat': 1, 'chang': 1, 'around': 1, 'us': 1, 'consequ': 1})
# Counter({'bark': 2, 'socdogfact': 1, 'think': 1, 'dog': 1, 'noth': 1, 'actual': 1, 'climat': 1, 'chang': 1})
# Counter({'zeddari': 1, 'thing': 1, 'indict': 1, 'made': 1, 'clear': 1, 'roger': 1, 'stone': 1, 'knew': 1, 'hoax': 1, 'push': 1, 'anyway': 1, 'becaus': 1, 'slime': 1, 'https': 1, 'co': 1})
# Counter({'hero': 3, 'music': 1, 'springsteen': 1, 'literari': 1, 'stephen': 1, 'king': 1, 'movi': 1, 'tarantino': 1, 'new': 1, 'releas': 1, 'year': 1, 'trump': 1, 'still': 1, 'incompet': 1, 'oaf': 1, 'climat': 1, 'chang': 1, 'scare': 1, 'crap': 1, 'moment': 1})
# Counter({'global': 2, 'kamalaharri': 1, 'unless': 1, 'speci': 1, 'protect': 1, 'extinct': 1, 'occur': 1, 'go': 1, 'green': 1, 'energi': 1, 'stop': 1, 'warm': 1, 'earth': 1, 'still': 1, 'massiv': 1, 'problem': 1, 'poison': 1, 'popul': 1})
# Counter({'perlmut': 1, 'mind': 1, 'hell': 1, 'freez': 1, 'thought': 1, 'lead': 1, 'free': 1, 'world': 1, 'https': 1, 'co': 1, 'by7dp39ar1': 1})
# Counter({'recycl': 2, 'good': 1, 'paper': 1, 'glass': 1, 'plastic': 1, 'tweet': 1, 'issu': 1, 'global': 1, 'warm': 1, 'thing': 1, 'https': 1, 'co': 1, 'qxqiuhx7j5': 1})
# Counter({'chelseaperetti': 1, 'pleas': 1, 'listen': 1, 'scientist': 1, 'global': 1, 'warm': 1, 'https': 1, 'co': 1, 'mo2cxuptml': 1})
# Counter({'like': 2, 'see': 1, 'post': 1, 'think': 1, 'one': 1, 'european': 1, 'countri': 1, 'wonder': 1, 'human': 1, 'meat': 1, 'tast': 1})
# Counter({'motherjon': 1, 'rememb': 1, 'republican': 1, 'plan': 1, 'confront': 1, 'climat': 1, 'chang': 1, 'offer': 1, 'spectacl': 1, 'https': 1, 'co': 1, '1r8qwog': 1})
# Counter({'thinkingheart': 1, 'prettypadmaja': 1, 'incindia': 1, 'link': 1, 'economi': 1, 'inc': 1, 'leader': 1, 'face': 1, 'court': 1, 'case': 1, 'linkag': 1})
# Counter({'hwasungalleri': 1, 'hwasa': 1, 'smack': 1, 'solar': 1, 'butt': 1, 'becaus': 1, 'lol': 1, 'https': 1, 'co': 1, 'j8b87ljxur': 1})
# Counter({'kellyikonba': 1, 'jame': 1, 'harden': 1, 'record': 1, 'fourth': 1, 'point': 1, 'tripl': 1, 'doubl': 1, 'career': 1, 'heap': 1, 'prais': 1, 'gerald': 1, 'green': 1, 'danuel': 1, 'ho': 1})
# Counter({'realsaavedra': 1, 'comment': 1, 'made': 1, 'green': 1, 'new': 1, 'deal': 1, 'document': 1, 'staff': 1, 'post': 1, 'congression': 1, 'websit': 1, 'yo': 1})
# Counter({'abdi_shakz': 1, 'global': 1, 'warm': 1, 'push': 1, 'summer': 1, 'forward': 1, 'https': 1, 'co': 1, 'redmqp8qgi': 1})
# Counter({'stclairashley': 1, 'sorri': 1, 'go': 1, 'take': 1, 'scienc': 1, 'lesson': 1, 'woman': 1, 'flunk': 1, 'dna': 1, 'test': 1, 'https': 1, 'co': 1, '9hppt04ttr': 1})
# Counter({'aoc': 1, 'climat': 1, 'cultist': 1, 'real': 1, 'scientist': 1, 'agre': 1, 'use': 1, 'inaccur': 1, 'data': 1, 'poor': 1, 'model': 1, 'make': 1, 'global': 1, 'warm': 1, 'fraud': 1, 'true': 1, 'believ': 1, 'like': 1, 'nsdp': 1, 'member': 1})
# Counter({'maramcavallaro': 1, 'yall': 1, 'tweet': 1, 'pray': 1, 'brazil': 1, 'talk': 1, 'amazon': 1, 'burn': 1, 'amp': 1, 'seem': 1, 'think': 1, 'natur': 1, 'disast': 1, 'ama': 1})
# Counter({'crushcuitur': 1, 'scari': 1, 'know': 1, 'probabl': 1, 'wont': 1, 'aliv': 1, 'kid': 1, 'grow': 1, 'old': 1, 'togeth': 1, 'someon': 1, 'becaus': 1, 'fact': 1})
# Counter({'danrath': 1, 'derelict': 1, 'duti': 1, 'grave': 1, 'word': 1, 'grant': 1, 'decad': 1, 'inact': 1, 'face': 1, 'overwhelm': 1, 'scientif': 1, 'evid': 1})
# Counter({'prisonplanet': 1, 'skeptic': 1, 'man': 1, 'made': 1, 'climat': 1, 'chang': 1, 'bill': 1, 'nye': 1, 'set': 1, 'fire': 1, 'plastic': 1, 'globe': 1, 'said': 1, 'f': 1, 'word': 1, 'bunch': 1})
# Counter({'tudelftonlin': 1, 'want': 1, 'becom': 1, 'solar': 1, 'energi': 1, 'engin': 1, 'deepen': 1, 'skill': 1, 'join': 1, 'onlin': 1, 'program': 1, 'gain': 1, 'knowledg': 1, 'skil': 1})
# Counter({'edkrassen': 1, 'instead': 1, 'give': 1, 'billion': 1, 'trump': 1, 'wall': 1, 'fix': 1, 'flint': 1, 'water': 1, 'crisi': 1, 'mil': 1, 'feed': 1, 'homeless': 1, 'vet': 1, 'meal': 1, 'day': 1})
# Counter({'globalchangebio': 1, 'local': 1, 'snow': 1, 'melt': 1, 'temperatur': 1, 'region': 1, 'sea': 1, 'ice': 1, 'explain': 1, 'variat': 1, 'spring': 1, 'phenolog': 1, 'coastal': 1, 'arctictundr': 1})
# Counter({'luisbaram': 1, 'global': 1, 'nuclear': 1, 'comfort': 1, 'outproduc': 1, 'wind': 1, 'solar': 1, 'combin': 1, 'whi': 1, 'person': 1, 'fear': 1, 'co2': 1, 'tend': 1, 'ignor': 1})
# Counter({'live': 1, 'oorja': 1, 'crowdfund': 1, 'campaign': 1, 'indiegogo': 1, 'pleas': 1, 'contribut': 1, 'show': 1, 'support': 1, 'mission': 1, 'bring': 1, 'oonnati': 1, 'afford': 1, 'solar': 1, 'irrig': 1, 'servic': 1, 'communiti': 1, 'peopl': 1, 'rural': 1, 'assam': 1, 'india': 1, 'https': 1, 'co': 1, '2j26fvd6bl': 1, 'morecropperdrop': 1})
# Counter({'farmer': 1, 'educ': 1, 'better': 1, 'deal': 1, 'effect': 1, 'climat': 1, 'chang': 1, 'dsglive': 1, 'uninindia': 1})
# Counter({'billion': 5, 'sensand': 1, 'world': 1, 'largest': 1, 'militari': 1, 'budget': 1, 'b': 1})
# Counter({'nasa': 2, 'climat': 2, 'chang': 2, '10new': 2, 'got': 1, 'interview': 1, 'scientist': 1, 'today': 1, 'talk': 1, 'arctic': 1, 'sea': 1, 'ice': 1, 'loss': 1, 'go': 1, 'discuss': 1, 'stori': 1, 'dure': 1, 'week': 1, 'septemb': 1, '16th': 1, 'https': 1, 'co': 1, 'eah4jlzfrh': 1})
# Counter({'sethdavishoop': 1, 'report': 1, 'issu': 1, 'trump': 1, 'administr': 1, 'amaz': 1, 'ever': 1, 'talk': 1, 'anyth': 1, 'els': 1, 'https': 1, 'co': 1})
# Counter({'scam': 2, 'amlivemon': 1, 'think': 1, 'peopl': 1, 'tri': 1, 'offset': 1, 'first': 1, 'debacl': 1, 'bail': 1, 'relat': 1, 'solar': 1, 'https': 1})
# Counter({'heofod': 1, 'eowdynga': 1, 'beorcost': 1, 'solar': 1, 'system': 1, 'cooper': 1, 'word': 1, 'approxim': 1, 'translat': 1, 'wane': 1, 'resist': 1, 'drag': 1})
# Counter({'cbcnewsbc': 1, 'climat': 1, 'chang': 1, 'caus': 1, 'glacier': 1, 'alberta': 1, 'british': 1, 'columbia': 1, 'yukon': 1, 'retreat': 1, 'faster': 1, 'ani': 1, 'time': 1, 'histori': 1, 'thr': 1})
# Counter({'answer': 1, 'convinc': 1, 'reason': 1, 'accept': 1, 'global': 1, 'warm': 1, 'https': 1, 'co': 1, '84gc4ynykk': 1})
# Counter({'msroberts0619': 1, 'dbongino': 1, 'nope': 1, 'russiag': 1, 'onli': 1, 'go': 1, 'coupl': 1, 'year': 1, 'real': 1, 'biggest': 1, 'media': 1, 'driven': 1, 'hoax': 1})
# Counter({'andy55116078': 1, 'hoax': 1, 'scientist': 1, 'proven': 1, 'man': 1, 'made': 1, 'climat': 1, 'chang': 1, 'absolut': 1, 'fals': 1, 'million': 1, 'year': 1, 'ago': 1, 'co2': 1, 'level': 1})
# Counter({'gavinnewsom': 1, 'oil': 1, 'gas': 1, 'firm': 1, 'spend': 1, 'million': 1, 'solut': 1, 'would': 1, 'address': 1, 'global': 1, 'threat': 1, 'climat': 1, 'chang': 1, 'sha': 1})
# Counter({'donoteat1': 1, 'thermodynam': 1, 'work': 1, 'https': 1, 'co': 1, 'x9npcgiyem': 1})
# Counter({'fuck': 2, 'cakedsnowbunni': 1, 'guy': 1, 'see': 1, 'happen': 1, 'give': 1, 'singl': 1, 'earth': 1, 'rapdili': 1, 'deterior': 1, 'bc': 1, 'human': 1})
# Counter({'pauledawson': 1, 'court': 1, 'said': 1, 'climat': 1, 'chang': 1, 'grave': 1, 'danger': 1, 'action': 1, 'govern': 1, 'violat': 1, 'right': 1, 'citizen': 1})
# Counter({'savetheturtles2': 1, 'glacier': 1, 'melt': 1, 'time': 1, 'faster': 1, '60s': 1, 'https': 1, 'co': 1, 'emyomxknfd': 1})
# Counter({'weather': 2, 'etheh': 1, 'top': 1, 'imag': 1, 'fictiti': 1, 'report': 1, 'imagin': 1, 'would': 1, 'like': 1, 'french': 1, 'tv': 1, 'documen': 1})
# Counter({'thegoodgodabov': 1, 'attent': 1, 'climat': 1, 'chang': 1, 'denier': 1, 'make': 1, 'stupid': 1, 'joke': 1, 'global': 1, 'warm': 1, 'everi': 1, 'time': 1, 'snow': 1})
# Counter({'https': 2, 'co': 2, 'social': 1, 'good': 1, 'summit': 1, '10th': 1, 'year': 1, 'tackl': 1, 'import': 1, 'issu': 1, 'time': 1, 'climat': 1, 'chang': 1, '2030now': 1, 'bring': 1, 'togeth': 1, 'global': 1, 'leader': 1, 'activist': 1, 'brand': 1, 'epic': 1, 'day': 1, 'construct': 1, 'dialogu': 1, 'onstag': 1, 'activ': 1, 'u2zxw3btiq': 1, 'nqcznzwcrp': 1})
# Counter({'mayor': 1, 'petebuttigieg': 1, 'instead': 1, 'minim': 1, 'gnd': 1, 'trm': 1, 'last': 1, 'night': 1, 'mayb': 1, 'studi': 1, 'actual': 1, 'sponsor': 1})
# Counter({'jhw229': 1, 'polar': 1, 'bear': 1, 'start': 1, 'practic': 1, 'cannib': 1, 'mother': 1, 'eat': 1, 'cub': 1, 'becaus': 1, 'drastic': 1, 'climat': 1, 'chang': 1})
# Counter({'gailslin': 1, 'aoc': 1, 'topic': 1, 'unrel': 1, 'wall': 1, 'stat': 1, 'confirm': 1, 'work': 1, 'amp': 1, 'climatechangehoax': 1, 'mani': 1, 'scientist': 1, 'disagre': 1})
# Counter({'undp': 1, 'world': 1, 'data': 1, 'generat': 1, 'past': 1, 'year': 1, 'unbiodiversitylab': 1, 'har': 1, 'spatialdata': 1, 'data4sdg': 1})
# Counter({'nachderma': 1, 'think': 1, 'sun': 1, 'stop': 1, 'work': 1, 'cold': 1, 'https': 1, 'co': 1, 'zvngnqsaen': 1})
# Counter({'rachaelven': 1, 'huge': 1, 'traffic': 1, 'blockag': 1, 'eleph': 1, 'castl': 1, 'morn': 1, 'extinctionr': 1, 'day': 1, 'two': 1, 'three': 1, 'climat': 1, 'chang': 1, 'pr': 1})
# Counter({'zerohedg': 1, 'tesla': 1, 'waiv': 1, 'solar': 1, 'remov': 1, 'fee': 1, 'rest': 1, 'sept': 1})
# Counter({'tweet': 2, 'inthesolarhq': 1, 'hey': 1, 'hope': 1, 'great': 1, 'day': 1, 'appreci': 1, 'owner': 1, 'tyrqh': 1, 'boy': 1, 'gi': 1})
# Counter({'iconicbaechu': 1, 'solar': 1, 'iren': 1, 'chorong': 1, 'group': 1, 'member': 1, 'mention': 1, 'age': 1, 'https': 1, 'co': 1, 'j1ggnlf2xx': 1})
# Counter({'auconserv': 2, 'jayjaysmd': 1, 'mt': 1, 'conserv': 1, 'parti': 1, 'welcom': 1, 'news': 1, 'australia': 1, 'longer': 1, 'contribut': 1})
# Counter({'ambassadorric': 1, 'yep': 1, 'kerri': 1, 'moron': 1, 'expert': 1, 'global': 1, 'warm': 1, 'much': 1, 'anyth': 1, 'els': 1, 'testifi': 1, 'congress': 1, 'idioci': 1, 'heard': 1, 'sleep': 1, 'holiday': 1})
# Counter({'nuclear': 1, 'power': 1, 'save': 1, 'world': 1, 'https': 1, 'co': 1, '3lj9hqszz9': 1})
# Counter({'stephenk': 1, 'get': 1, 'juic': 1, 'power': 1, 'tesla': 1, 'solar': 1, 'https': 1, 'co': 1, 'xu1smxqccj': 1})
# Counter({'berniesand': 1, 'believ': 1, 'climat': 1, 'chang': 1, 'congress': 1})
# Counter({'physicsj': 1, 'spent': 1, 'holiday': 1, 'make': 1, 'anim': 1, 'shown': 1, 'exact': 1, 'rotat': 1, 'period': 1, 'amp': 1, 'axial': 1, 'tilt': 1, 'eight': 1, 'largest': 1, 'planet': 1})
# Counter({'johndolph': 1, 'mitt': 1, 'romney': 1, 'want': 1, 'carbon': 1, 'tax': 1, 'say': 1, 'climat': 1, 'chang': 1, 'happen': 1, 'insist': 1, 'work': 1, 'left': 1, 'behind': 1, 'like': 1, 'coal': 1, 'mi': 1})
# Counter({'aoc': 1, 'tri': 1, 'justifi': 1, 'ignor': 1, 'one': 1, 'greatest': 1, 'threat': 1, 'human': 1, 'imperil': 1, 'c': 1})
# Counter({'stevesilberman': 1, 'climat': 1, 'chang': 1, 'look': 1, 'like': 1, 'former': 1, 'town': 1, 'paradis': 1, 'ca': 1, 'photo': 1, 'karlmondon': 1, 'https': 1, 'co': 1, 'af9dwo940w': 1})
# Counter({'care': 1, 'astrophysicist': 1, 'scientif': 1, 'author': 1, 'make': 1, 'claim': 1, 'whether': 1, 'climat': 1, 'chang': 1, 'real': 1})
# Counter({'peytnhaag': 1, 'climat': 1, 'chang': 1, 'kill': 1, 'https': 1, 'co': 1, 'tzpdzzjk4k': 1})
# Counter({'aoc': 1, 'gop': 1, 'senat': 1, 'use': 1, 'congression': 1, 'allow': 1, 'print': 1, 'aquaman': 1, 'poster': 1, 'themselv': 1, 'argu': 1, 'greennewd': 1, 'save': 1})
# Counter({'ancient': 1, 'rock': 1, 'align': 1, 'solar': 1, 'track': 1, 'https': 1, 'co': 1, '9zubrhi3wl': 1})
# Counter({'jacob_frey': 1, 'clean': 1, 'energi': 1, 'never': 1, 'tast': 1, 'good': 1, 'freshenergi': 1, 'rob': 1, 'davi': 1, '56brew': 1, 'amp': 1, 'sarahclarke9': 1, 'liter': 1, 'first': 1, 'investor': 1, 'w': 1})
# Counter({'climat': 2, 'suhlenbrook': 1, 'water': 1, 'manag': 1, 'action': 1, 'key': 1, 'chang': 1, 'adapt': 1, 'sometim': 1, 'forgotten': 1, 'mitig': 1, 'chan': 1})
# Counter({'billgat': 1, 'great': 1, 'see': 1, 'leader': 1, 'washington': 1, 'talk': 1, 'acceler': 1, 'energi': 1, 'innov': 1, 'fight': 1, 'climat': 1, 'chang': 1, 'op': 1, 'ed': 1, 'fro': 1})
# Counter({'amp': 3, 'candicebergenmp': 1, 'joycemurray': 1, 'time': 1, 'stand': 1, 'piec': 1, 'scheme': 1, 'togeth': 1, 'cdns': 1, 'candac': 1, 'climat': 1, 'chang': 1, 'rule': 1, 'tax': 1, 'part': 1, '1992s': 1, 'agenda': 1, 'action': 1, 'plan': 1, 'un': 1, 'use': 1, 'bring': 1, 'global': 1, 'gov': 1, 'eras': 1, 'nation': 1, 'state': 1, 'justintrudeau': 1, 'sold': 1, 'canada': 1, 'especi': 1, 'alberta': 1, 'globalist': 1})
# Counter({'aoc': 1, 'happen': 1, 'https': 1, 'co': 1, 'al9q6yubuh': 1})
# Counter({'nunni': 1, 'fear': 1, 'monger': 1, 'govern': 1, 'sponsorship': 1, 'particular': 1, 'point': 1, 'view': 1, 'human': 1, 'activ': 1, 'contr': 1})
# Counter({'fuck': 2, 'cakedsnowbunni': 1, 'guy': 1, 'see': 1, 'happen': 1, 'give': 1, 'singl': 1, 'earth': 1, 'rapdili': 1, 'deterior': 1, 'bc': 1, 'human': 1})
# Counter({'npr': 1, 'urban': 1, 'tree': 1, 'increas': 1, 'seen': 1, 'necessari': 1, 'combat': 1, 'effect': 1, 'climat': 1, 'chang': 1, 'protest': 1, 'erupt': 1, 'around': 1, 'harvard': 1, 'divinit': 1})
# Counter({'miskeencor': 1, 'much': 1, 'anxieti': 1, 'climat': 1, 'chang': 1, 'lol': 1, 'point': 1, 'plan': 1, 'futur': 1, 'rate': 1, 'ha': 1})
# Counter({'presid': 2, 'kenolin1': 1, 'day': 1, 'democrat': 1, 'accus': 1, 'babi': 1, 'killer': 1, 'socialist': 1, 'open': 1, 'border': 1})
# Counter({'cnusd': 1, 'cen10huski': 1, 'student': 1, 'work': 1, 'boat': 1, 'solar': 1, 'cup': 1, 'competit': 1, 'cen10': 1, 'cnusdfuturereadi': 1, 'https': 1, 'co': 1, 'fqnvwx0qut': 1})
# Counter({'robrein': 1, 'never': 1, 'ask': 1, 'follow': 1, 'retweet': 1, 'want': 1, 'rid': 1, 'us': 1, 'lie': 1, 'crimin': 1, 'must': 1, 'pledg': 1, 'support': 1})
# Counter({'jbwallac': 1, 'australia': 1, 'pm': 1, 'advis': 1, 'say': 1, 'climat': 1, 'chang': 1, 'un': 1, 'led': 1, 'ruse': 1, 'establish': 1, 'new': 1, 'world': 1, 'order': 1, 'telegraph': 1, 'https': 1, 'co': 1, 'splg9qstz7': 1})
# Counter({'everi': 1, 'day': 1, 'peopl': 1, 'head': 1, 'citi': 1, 'region': 1, 'council': 1, 'trust': 1, 'make': 1, 'scienc': 1, 'base': 1, 'decis': 1, 'improv': 1, 'health': 1, 'wellb': 1, 'climat': 1, 'chang': 1, 'denial': 1, 'incompat': 1, 'job': 1, 'descript': 1, 'https': 1, 'co': 1, 'qlezgq9cmm': 1})
# Counter({'r2d2resist': 1, 'climat': 1, 'chang': 1, 'action': 1, 'prioriti': 1, 'hous': 1, 'year': 1, 'issu': 1, 'import': 1, 'veri': 1, 'surviv': 1, 'follow': 1, 'ou': 1})
# Counter({'maramcavallaro': 1, 'yall': 1, 'tweet': 1, 'pray': 1, 'brazil': 1, 'talk': 1, 'amazon': 1, 'burn': 1, 'amp': 1, 'seem': 1, 'think': 1, 'natur': 1, 'disast': 1, 'ama': 1})
# Counter({'weight': 2, 'blanket': 2, 'samreich': 1, 'befor': 1, 'get': 1, 'pee': 1, 'twice': 1, 'wake': 1, '8am': 1, 'sharp': 1, 'dream': 1, 'poop': 1, 'bed': 1})
# Counter({'democracynow': 1, 'among': 1, 'danger': 1, 'place': 1, 'environmentalist': 1, 'philippin': 1, 'guatemala': 1, 'brazil': 1, 'pace': 1, 'vio': 1})
# Counter({'taylor': 1, 'state': 1, 'aim': 1, 'creat': 1, 'reliabl': 1, 'cheaper': 1, 'electr': 1, 'grid': 1, 'coal': 1, 'expens': 1, 'unreli': 1, 'auspol': 1, 'votethemout': 1, 'https': 1, 'co': 1, 'zkc48rhw9s': 1})
# Counter({'cnnbrk': 1, 'massiv': 1, 'feder': 1, 'climat': 1, 'chang': 1, 'report': 1, 'due': 1, 'next': 1, 'month': 1, 'today': 1, 'warn': 1, 'devast': 1, 'health': 1, 'econom': 1, 'cost': 1})
# Counter({'maramcavallaro': 1, 'yall': 1, 'tweet': 1, 'pray': 1, 'brazil': 1, 'talk': 1, 'amazon': 1, 'burn': 1, 'amp': 1, 'seem': 1, 'think': 1, 'natur': 1, 'disast': 1, 'ama': 1})
# Counter({'johnjharwood': 1, 'husband': 1, 'billionair': 1, 'coal': 1, 'mine': 1, 'magnat': 1, 'https': 1, 'co': 1, 'kliu7orywg': 1})
# Counter({'nonesoblind': 1, 'thomas1774pain': 1, 'global': 1, 'warm': 1, 'south': 1, 'https': 1, 'co': 1, 'nrsvm5tp6w': 1})
# Counter({'justinmarksdg': 1, 'ridicul': 1, 'heart': 1, 'break': 1, 'invest': 1, 'live': 1, 'sport': 1, 'control': 1, 'destini': 1, 'mani': 1, 'htt': 1})
# Counter({'chang': 2, 'danfisha': 1, 'offens': 1, 'govern': 1, 'acknowledg': 1, 'serious': 1, 'climat': 1, 'activ': 1, 'make': 1, 'larg': 1, 'scale': 1, 'order': 1})
# Number of Climate Change Tweets: 376
# Number of Natural Disaster Tweets: 9
# Number of Climate Change Acceptance Tweets: 46
# Number of Climate Change Denial Tweets: 16
# Number of Sentamental Tweets: 48
# Number of Non-sentamental Disaster Tweets: 45
